# %% [markdown]
# # Basic data exploration

# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_csv("may-october(5 min).csv")
d
# Out:
#                    Time       InverterSN  Data LoggerSN Alert Details  \
# 0      2022/05/02 05:55  110470185160082      706238511           NaN
# 1      2022/05/02 06:00  110470185160082      706238511           NaN
# 2      2022/05/02 06:05  110470185160082      706238511           NaN
# 3      2022/05/02 06:12  110470185160082      706238511           NaN
# 4      2022/05/02 06:17  110470185160082      706238511           NaN
# ...                 ...              ...            ...           ...
# 23272  2022/10/09 17:53  110470185160082      706238511           NaN
# 23273  2022/10/09 17:58  110470185160082      706238511           NaN
# 23274  2022/10/09 18:03  110470185160082      706238511           NaN
# 23275  2022/10/09 18:09  110470185160082      706238511           NaN
# 23276  2022/10/09 18:14  110470185160082      706238511           NaN
#
#       Alert Code  DC Voltage PV1(V)  DC Voltage PV2(V)  DC Voltage PV3(V)  \
# 0            NaN               92.2              165.4               94.8
# 1            NaN              200.1              236.2              200.1
# 2            NaN              207.8              344.2              216.1
# 3            NaN              228.1              596.1              228.0
# 4            NaN              240.1              608.1              240.1
# ...          ...                ...                ...                ...
# 23272        NaN              200.0              546.6              200.0
# 23273        NaN              199.9              200.1              476.1
# 23274        NaN              457.3              200.0              476.3
# 23275        NaN              437.6              420.4              382.1
# 23276        NaN              193.3              258.8              184.9
#
#        DC Voltage PV4(V)  DC Current1(A)  ...  AC Output Frequency R(Hz)  \
# 0                   86.5             0.1  ...                      50.00
# 1                  536.4             0.1  ...                      50.10
# 2                  536.4             0.1  ...                      50.11
# 3                  536.3             0.2  ...                      50.01
# 4                  536.6             0.2  ...                      50.06
# ...                  ...             ...  ...                        ...
# 23272              200.0             0.1  ...                      49.99
# 23273              509.6             0.1  ...                      50.03
# 23274              509.6             0.1  ...                      50.06
# 23275              389.7             0.1  ...                      49.96
# 23276              188.8             0.1  ...                      50.03
#
#        Generation of Last Month (Active)(kWh)  Daily Generation (Active)(kWh)  \
# 0                                        3164                             0.0
# 1                                        3164                             0.0
# 2                                        3164                             0.0
# 3                                        3164                             0.0
# 4                                        3164                             0.0
# ...                                       ...                             ...
# 23272                                    2835                            82.4
# 23273                                    2835                            82.4
# 23274                                    2835                            82.4
# 23275                                    2835                            82.4
# 23276                                    2835                            82.4
#
#        Total Generation (Active)(kWh)  Power Grid Total Apparent Power(VA)  \
# 0                            117029.0                                   80
# 1                            117029.0                                   20
# 2                            117029.0                                   30
# 3                            117029.0                                  190
# 4                            117029.0                                  160
# ...                               ...                                  ...
# 23272                        133462.0                                   80
# 23273                        133462.0                                   70
# 23274                        133462.0                                  140
# 23275                        133462.0                                  140
# 23276                        133462.0                                  130
#
#        Grid Power Factor  Inverter Temperature(℃)  Inverter Status  \
# 0                    1.0                     32.9             1022
# 1                    1.0                     34.1             1022
# 2                    1.0                     34.4             1022
# 3                    1.0                     34.9             1022
# 4                    1.0                     35.3             1022
# ...                  ...                      ...              ...
# 23272                1.0                     37.8             1022
# 23273                1.0                     37.6             1022
# 23274                1.0                     37.4             1022
# 23275                1.0                     37.1             1022
# 23276                1.0                     36.8             1022
#
#        Generation Yesterday(kWh)       System Time
# 0                          126.9     22-5-2 6:16:1
# 1                          126.9    22-5-2 6:21:39
# 2                          126.9    22-5-2 6:26:12
# 3                          126.9    22-5-2 6:33:15
# 4                          126.9    22-5-2 6:38:44
# ...                          ...               ...
# 23272                      131.9  22-10-9 18:22:15
# 23273                      131.9  22-10-9 18:26:40
# 23274                      131.9  22-10-9 18:32:14
# 23275                      131.9  22-10-9 18:37:44
# 23276                      131.9  22-10-9 18:43:15
#
# [23277 rows x 31 columns]

# %%
d.columns
# Out:
# Index(['Time', 'InverterSN', 'Data LoggerSN', 'Alert Details', 'Alert Code',
#        'DC Voltage PV1(V)', 'DC Voltage PV2(V)', 'DC Voltage PV3(V)',
#        'DC Voltage PV4(V)', 'DC Current1(A)', 'DC Current2(A)',
#        'DC Current3(A)', 'DC Current4(A)', 'Total DC Input Power(W)',
#        'AC Voltage R/U/A(V)', 'AC Voltage S/V/B(V)', 'AC Voltage T/W/C(V)',
#        'AC Current R/U/A(A)', 'AC Current S/V/B(A)', 'AC Current T/W/C(A)',
#        'AC Output Total Power (Active)(W)', 'AC Output Frequency R(Hz)',
#        'Generation of Last Month (Active)(kWh)',
#        'Daily Generation (Active)(kWh)', 'Total Generation (Active)(kWh)',
#        'Power Grid Total Apparent Power(VA)', 'Grid Power Factor',
#        'Inverter Temperature(℃)', 'Inverter Status',
#        'Generation Yesterday(kWh)', 'System Time'],
#       dtype='object')

# %%
d['InverterSN'].unique
# Out:
# <bound method Series.unique of 0        110470185160082
# 1        110470185160082
# 2        110470185160082
# 3        110470185160082
# 4        110470185160082
#               ...
# 23272    110470185160082
# 23273    110470185160082
# 23274    110470185160082
# 23275    110470185160082
# 23276    110470185160082
# Name: InverterSN, Length: 23277, dtype: int64>

# %%
d['InverterSN'].value_counts()
# Out:
# 110470185160082    23277
# Name: InverterSN, dtype: int64

# %%
d['Data LoggerSN'].unique
# Out:
# <bound method Series.unique of 0        706238511
# 1        706238511
# 2        706238511
# 3        706238511
# 4        706238511
#            ...
# 23272    706238511
# 23273    706238511
# 23274    706238511
# 23275    706238511
# 23276    706238511
# Name: Data LoggerSN, Length: 23277, dtype: int64>

# %%
d['Data LoggerSN'].value_counts()
# Out:
# 706238511    23277
# Name: Data LoggerSN, dtype: int64

# %%
d['Inverter Status'].unique
# Out:
# <bound method Series.unique of 0        1022
# 1        1022
# 2        1022
# 3        1022
# 4        1022
#          ...
# 23272    1022
# 23273    1022
# 23274    1022
# 23275    1022
# 23276    1022
# Name: Inverter Status, Length: 23277, dtype: object>

# %%
d['Inverter Status'].value_counts()
# Out:
# 1022       22835
# 1025         415
# Standby       27
# Name: Inverter Status, dtype: int64

# %%
d.shape
# Out:
# (23277, 31)

# %%
d.dtypes
# Out:
# Time                                       object
# InverterSN                                  int64
# Data LoggerSN                               int64
# Alert Details                              object
# Alert Code                                 object
# DC Voltage PV1(V)                         float64
# DC Voltage PV2(V)                         float64
# DC Voltage PV3(V)                         float64
# DC Voltage PV4(V)                         float64
# DC Current1(A)                            float64
# DC Current2(A)                            float64
# DC Current3(A)                            float64
# DC Current4(A)                            float64
# Total DC Input Power(W)                     int64
# AC Voltage R/U/A(V)                       float64
# AC Voltage S/V/B(V)                       float64
# AC Voltage T/W/C(V)                       float64
# AC Current R/U/A(A)                       float64
# AC Current S/V/B(A)                       float64
# AC Current T/W/C(A)                       float64
# AC Output Total Power (Active)(W)           int64
# AC Output Frequency R(Hz)                 float64
# Generation of Last Month (Active)(kWh)      int64
# Daily Generation (Active)(kWh)            float64
# Total Generation (Active)(kWh)            float64
# Power Grid Total Apparent Power(VA)         int64
# Grid Power Factor                         float64
# Inverter Temperature(℃)                   float64
# Inverter Status                            object
# Generation Yesterday(kWh)                 float64
# System Time                                object
# dtype: object

# %%
x=d.columns
l=[]
for i in range(1,len(x)-1):
    l.append(d[x[i]].value_counts())
for i in l:
    print(i)
# Out:
# 110470185160082    23277
# Name: InverterSN, dtype: int64
# 706238511    23277
# Name: Data LoggerSN, dtype: int64
# N    329
# G     86
# Name: Alert Details, dtype: int64
# 1015H    329
# 1012H     78
# 1010H      5
# 1011H      3
# Name: Alert Code, dtype: int64
# 200.1    142
# 632.1    119
# 200.0    119
# 640.1    117
# 624.0    116
#         ...
# 305.5      1
# 732.8      1
# 135.4      1
# 285.4      1
# 193.3      1
# Name: DC Voltage PV1(V), Length: 2456, dtype: int64
# 200.1    116
# 200.0    101
# 616.1     86
# 612.1     82
# 643.9     82
#         ...
# 549.3      1
# 394.3      1
# 163.6      1
# 207.4      1
# 258.8      1
# Name: DC Voltage PV2(V), Length: 2355, dtype: int64
# 200.1    154
# 200.0    148
# 620.0    118
# 636.1    115
# 632.1    112
#         ...
# 454.9      1
# 505.7      1
# 506.0      1
# 506.3      1
# 184.9      1
# Name: DC Voltage PV3(V), Length: 2582, dtype: int64
# 200.0    173
# 671.9    130
# 672.1    129
# 200.1    129
# 672.0    127
#         ...
# 146.2      1
# 243.1      1
# 405.5      1
# 504.7      1
# 188.8      1
# Name: DC Voltage PV4(V), Length: 2589, dtype: int64
# 0.1     1876
# 0.2      912
# 0.3      765
# 0.4      629
# 0.7      580
#         ...
# 10.0       2
# 10.5       2
# 10.3       1
# 10.9       1
# 11.6       1
# Name: DC Current1(A), Length: 107, dtype: int64
# 0.1     1190
# 0.2      632
# 0.3      505
# 0.0      428
# 0.4      411
#         ...
# 17.7      15
# 17.3      13
# 17.9      10
# 18.1       6
# 18.4       1
# Name: DC Current2(A), Length: 183, dtype: int64
# 0.1     1938
# 0.2      940
# 0.3      754
# 0.4      631
# 0.5      617
#         ...
# 11.3       1
# 11.1       1
# 11.2       1
# 10.1       1
# 10.2       1
# Name: DC Current3(A), Length: 110, dtype: int64
# 0.1     2032
# 0.2      836
# 0.3      810
# 0.4      683
# 0.5      590
#         ...
# 11.1       1
# 10.3       1
# 10.9       1
# 11.4       1
# 10.7       1
# Name: DC Current4(A), Length: 109, dtype: int64
# 0        428
# 80        67
# 169       34
# 166       33
# 139       32
#         ...
# 11159      1
# 6328       1
# 16150      1
# 17382      1
# 1764       1
# Name: Total DC Input Power(W), Length: 13181, dtype: int64
# 234.6    403
# 235.8    402
# 235.5    399
# 236.2    380
# 233.9    379
#         ...
# 200.3      1
# 201.2      1
# 202.5      1
# 196.5      1
# 268.2      1
# Name: AC Voltage R/U/A(V), Length: 218, dtype: int64
# 237.7    411
# 237.4    400
# 237.1    397
# 236.2    396
# 236.5    394
#         ...
# 203.1      1
# 204.1      1
# 202.2      1
# 203.5      1
# 268.5      1
# Name: AC Voltage S/V/B(V), Length: 209, dtype: int64
# 239.0    402
# 235.8    400
# 237.1    396
# 238.7    392
# 236.8    389
#         ...
# 199.0      1
# 206.6      1
# 201.6      1
# 186.9      1
# 200.0      1
# Name: AC Voltage T/W/C(V), Length: 210, dtype: int64
# 0.0     1245
# 0.1      500
# 0.2      272
# 0.4      256
# 1.7      231
#         ...
# 37.1       1
# 40.6       1
# 42.5       1
# 38.0       1
# 39.3       1
# Name: AC Current R/U/A(A), Length: 403, dtype: int64
# 0.0     1245
# 0.1      500
# 0.2      272
# 0.4      256
# 1.5      253
#         ...
# 36.0       1
# 38.4       1
# 39.9       1
# 40.1       1
# 39.7       1
# Name: AC Current S/V/B(A), Length: 399, dtype: int64
# 0.0     1245
# 0.1      500
# 0.2      272
# 0.4      256
# 1.9      221
#         ...
# 39.1       1
# 40.0       1
# 37.7       1
# 39.4       1
# 41.8       1
# Name: AC Current T/W/C(A), Length: 399, dtype: int64
# 20       1443
# 0         428
# 160        66
# 210        65
# 100        62
#          ...
# 26100       1
# 25250       1
# 15710       1
# 26250       1
# 24540       1
# Name: AC Output Total Power (Active)(W), Length: 2617, dtype: int64
# 49.99    3466
# 50.00    2040
# 50.03    1991
# 50.01    1752
# 50.06    1570
#          ...
# 49.53       1
# 49.50       1
# 51.42       1
# 51.51       1
# 51.22       1
# Name: AC Output Frequency R(Hz), Length: 113, dtype: int64
# 2544    4672
# 3164    4532
# 3833    4528
# 3225    4294
# 3374    4268
# 2835     983
# Name: Generation of Last Month (Active)(kWh), dtype: int64
# 0.0      849
# 0.1      376
# 0.2      206
# 0.3      165
# 0.4      146
#         ...
# 153.3      1
# 153.4      1
# 149.4      1
# 153.6      1
# 142.2      1
# Name: Daily Generation (Active)(kWh), Length: 1535, dtype: int64
# 126395.0    54
# 133206.0    54
# 127161.0    43
# 124934.0    42
# 126091.0    42
#             ..
# 119746.0     1
# 119748.0     1
# 119750.0     1
# 119752.0     1
# 127416.0     1
# Name: Total Generation (Active)(kWh), Length: 12584, dtype: int64
# 0        507
# 50       232
# 100      204
# 80       151
# 40       148
#         ...
# 21810      1
# 27490      1
# 25750      1
# 28000      1
# 24860      1
# Name: Power Grid Total Apparent Power(VA), Length: 2607, dtype: int64
# 1.0    23277
# Name: Grid Power Factor, dtype: int64
# 41.0    135
# 35.3    116
# 42.0    109
# 40.0    105
# 44.0    100
#        ...
# 72.6      1
# 72.5      1
# 72.7      1
# 72.1      1
# 25.1      1
# Name: Inverter Temperature(℃), Length: 489, dtype: int64
# 1022       22835
# 1025         415
# Standby       27
# Name: Inverter Status, dtype: int64
# 118.1    311
# 118.9    309
# 29.8     292
# 119.9    291
# 79.3     287
#         ...
# 124.7    108
# 111.9    105
# 93.3      82
# 78.1      19
# 0.0        5
# Name: Generation Yesterday(kWh), Length: 153, dtype: int64

# %% [markdown]
# Conclusion:Alert details, Alert code, Grid power factor, Inverter status attributes doesnt have much unique values

# %%
d=d[['Time', 'DC Voltage PV1(V)', 'DC Voltage PV2(V)', 'DC Voltage PV3(V)',
       'DC Voltage PV4(V)', 'DC Current1(A)', 'DC Current2(A)',
       'DC Current3(A)', 'DC Current4(A)', 'Total DC Input Power(W)',
       'AC Voltage R/U/A(V)', 'AC Voltage S/V/B(V)', 'AC Voltage T/W/C(V)',
       'AC Current R/U/A(A)', 'AC Current S/V/B(A)', 'AC Current T/W/C(A)',
       'AC Output Total Power (Active)(W)', 'AC Output Frequency R(Hz)',
       'Generation of Last Month (Active)(kWh)',
       'Daily Generation (Active)(kWh)', 'Total Generation (Active)(kWh)',
       'Power Grid Total Apparent Power(VA)',
       'Inverter Temperature(℃)',
       'Generation Yesterday(kWh)']]

# %%
d.head(10)
# Out:
#                Time  DC Voltage PV1(V)  DC Voltage PV2(V)  DC Voltage PV3(V)  \
# 0  2022/05/02 05:55               92.2              165.4               94.8
# 1  2022/05/02 06:00              200.1              236.2              200.1
# 2  2022/05/02 06:05              207.8              344.2              216.1
# 3  2022/05/02 06:12              228.1              596.1              228.0
# 4  2022/05/02 06:17              240.1              608.1              240.1
# 5  2022/05/02 06:22              268.1              603.6              267.8
# 6  2022/05/02 06:27              548.0              611.8              523.9
# 7  2022/05/02 06:33              616.0              624.0              632.1
# 8  2022/05/02 06:38              628.1              628.0              628.3
# 9  2022/05/02 06:43              627.8              635.3              628.1
#
#    DC Voltage PV4(V)  DC Current1(A)  DC Current2(A)  DC Current3(A)  \
# 0               86.5             0.1             0.1             0.1
# 1              536.4             0.1             0.2             0.1
# 2              536.4             0.1             0.2             0.1
# 3              536.3             0.2             0.3             0.2
# 4              536.6             0.2             0.3             0.2
# 5              252.1             0.2             0.4             0.2
# 6              452.3             0.3             0.5             0.3
# 7              664.1             0.3             0.6             0.3
# 8              660.0             0.4             0.8             0.4
# 9              667.7             0.6             1.0             0.6
#
#    DC Current4(A)  Total DC Input Power(W)  ...  AC Current S/V/B(A)  \
# 0             0.1                       43  ...                  0.0
# 1             0.1                      140  ...                  0.1
# 2             0.1                      164  ...                  0.2
# 3             0.2                      377  ...                  0.4
# 4             0.2                      385  ...                  0.5
# 5             0.2                      399  ...                  0.5
# 6             0.3                      763  ...                  0.9
# 7             0.3                      948  ...                  1.4
# 8             0.4                     1268  ...                  1.7
# 9             0.5                     1722  ...                  2.4
#
#    AC Current T/W/C(A)  AC Output Total Power (Active)(W)  \
# 0                  0.0                                 20
# 1                  0.1                                 30
# 2                  0.2                                 40
# 3                  0.4                                200
# 4                  0.5                                160
# 5                  0.5                                220
# 6                  0.9                                500
# 7                  1.3                                740
# 8                  1.7                               1080
# 9                  2.3                               1540
#
#    AC Output Frequency R(Hz)  Generation of Last Month (Active)(kWh)  \
# 0                      50.00                                    3164
# 1                      50.10                                    3164
# 2                      50.11                                    3164
# 3                      50.01                                    3164
# 4                      50.06                                    3164
# 5                      50.05                                    3164
# 6                      50.03                                    3164
# 7                      49.99                                    3164
# 8                      50.06                                    3164
# 9                      50.01                                    3164
#
#    Daily Generation (Active)(kWh)  Total Generation (Active)(kWh)  \
# 0                             0.0                        117029.0
# 1                             0.0                        117029.0
# 2                             0.0                        117029.0
# 3                             0.0                        117029.0
# 4                             0.0                        117029.0
# 5                             0.1                        117029.0
# 6                             0.1                        117029.0
# 7                             0.1                        117029.0
# 8                             0.2                        117029.0
# 9                             0.3                        117029.0
#
#    Power Grid Total Apparent Power(VA)  Inverter Temperature(℃)  \
# 0                                   80                     32.9
# 1                                   20                     34.1
# 2                                   30                     34.4
# 3                                  190                     34.9
# 4                                  160                     35.3
# 5                                  240                     35.4
# 6                                  480                     35.7
# 7                                  710                     36.1
# 8                                 1080                     36.5
# 9                                 1530                     36.8
#
#    Generation Yesterday(kWh)
# 0                      126.9
# 1                      126.9
# 2                      126.9
# 3                      126.9
# 4                      126.9
# 5                      126.9
# 6                      126.9
# 7                      126.9
# 8                      126.9
# 9                      126.9
#
# [10 rows x 24 columns]

# %%
d.isna().sum()
# Out:
# Time                                      0
# DC Voltage PV1(V)                         0
# DC Voltage PV2(V)                         0
# DC Voltage PV3(V)                         0
# DC Voltage PV4(V)                         0
# DC Current1(A)                            0
# DC Current2(A)                            0
# DC Current3(A)                            0
# DC Current4(A)                            0
# Total DC Input Power(W)                   0
# AC Voltage R/U/A(V)                       0
# AC Voltage S/V/B(V)                       0
# AC Voltage T/W/C(V)                       0
# AC Current R/U/A(A)                       0
# AC Current S/V/B(A)                       0
# AC Current T/W/C(A)                       0
# AC Output Total Power (Active)(W)         0
# AC Output Frequency R(Hz)                 0
# Generation of Last Month (Active)(kWh)    0
# Daily Generation (Active)(kWh)            0
# Total Generation (Active)(kWh)            0
# Power Grid Total Apparent Power(VA)       0
# Inverter Temperature(℃)                   0
# Generation Yesterday(kWh)                 0
# dtype: int64

# %% [markdown]
# # Converting to datetime

# %%
d.dtypes
# Out:
# Time                                       object
# DC Voltage PV1(V)                         float64
# DC Voltage PV2(V)                         float64
# DC Voltage PV3(V)                         float64
# DC Voltage PV4(V)                         float64
# DC Current1(A)                            float64
# DC Current2(A)                            float64
# DC Current3(A)                            float64
# DC Current4(A)                            float64
# Total DC Input Power(W)                     int64
# AC Voltage R/U/A(V)                       float64
# AC Voltage S/V/B(V)                       float64
# AC Voltage T/W/C(V)                       float64
# AC Current R/U/A(A)                       float64
# AC Current S/V/B(A)                       float64
# AC Current T/W/C(A)                       float64
# AC Output Total Power (Active)(W)           int64
# AC Output Frequency R(Hz)                 float64
# Generation of Last Month (Active)(kWh)      int64
# Daily Generation (Active)(kWh)            float64
# Total Generation (Active)(kWh)            float64
# Power Grid Total Apparent Power(VA)         int64
# Inverter Temperature(℃)                   float64
# Generation Yesterday(kWh)                 float64
# dtype: object

# %%
d.loc[:,'Time'] = d['Time'].astype('string')#converted time to string
d.dtypes
# Out:
# c:\Users\Ananya Peruru\anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# Time                                       string
# DC Voltage PV1(V)                         float64
# DC Voltage PV2(V)                         float64
# DC Voltage PV3(V)                         float64
# DC Voltage PV4(V)                         float64
# DC Current1(A)                            float64
# DC Current2(A)                            float64
# DC Current3(A)                            float64
# DC Current4(A)                            float64
# Total DC Input Power(W)                     int64
# AC Voltage R/U/A(V)                       float64
# AC Voltage S/V/B(V)                       float64
# AC Voltage T/W/C(V)                       float64
# AC Current R/U/A(A)                       float64
# AC Current S/V/B(A)                       float64
# AC Current T/W/C(A)                       float64
# AC Output Total Power (Active)(W)           int64
# AC Output Frequency R(Hz)                 float64
# Generation of Last Month (Active)(kWh)      int64
# Daily Generation (Active)(kWh)            float64
# Total Generation (Active)(kWh)            float64
# Power Grid Total Apparent Power(VA)         int64
# Inverter Temperature(℃)                   float64
# Generation Yesterday(kWh)                 float64
# dtype: object

# %%
d['Time']= pd.to_datetime(d['Time'])
d.dtypes
# Out:
# C:\Users\ANANYA~1\AppData\Local\Temp/ipykernel_18568/2473265570.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['Time']= pd.to_datetime(d['Time'])
# Time                                      datetime64[ns]
# DC Voltage PV1(V)                                float64
# DC Voltage PV2(V)                                float64
# DC Voltage PV3(V)                                float64
# DC Voltage PV4(V)                                float64
# DC Current1(A)                                   float64
# DC Current2(A)                                   float64
# DC Current3(A)                                   float64
# DC Current4(A)                                   float64
# Total DC Input Power(W)                            int64
# AC Voltage R/U/A(V)                              float64
# AC Voltage S/V/B(V)                              float64
# AC Voltage T/W/C(V)                              float64
# AC Current R/U/A(A)                              float64
# AC Current S/V/B(A)                              float64
# AC Current T/W/C(A)                              float64
# AC Output Total Power (Active)(W)                  int64
# AC Output Frequency R(Hz)                        float64
# Generation of Last Month (Active)(kWh)             int64
# Daily Generation (Active)(kWh)                   float64
# Total Generation (Active)(kWh)                   float64
# Power Grid Total Apparent Power(VA)                int64
# Inverter Temperature(℃)                          float64
# Generation Yesterday(kWh)                        float64
# dtype: object

# %%
d.head()
d.to_csv('file_name.csv')

# %%
from datetime import date
dates=d
s=(dates['Time'].apply(lambda x: x.date()).value_counts() >= 80) 
s
# Out:
# 2022-06-07     True
# 2022-06-14     True
# 2022-06-08     True
# 2022-08-03     True
# 2022-06-05     True
#               ...
# 2022-05-27     True
# 2022-09-29     True
# 2022-06-29     True
# 2022-10-05    False
# 2022-10-06    False
# Name: Time, Length: 159, dtype: bool

# %%
d2=pd.read_csv("new_file.csv")
d2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\ANANYA~1\AppData\Local\Temp/ipykernel_18568/1797101486.py in <module>
# ----> 1 d2=pd.read_csv("new_file.csv")
#       2 d2
#
# c:\Users\Ananya Peruru\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\Ananya Peruru\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# c:\Users\Ananya Peruru\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# c:\Users\Ananya Peruru\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# c:\Users\Ananya Peruru\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# c:\Users\Ananya Peruru\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# c:\Users\Ananya Peruru\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# c:\Users\Ananya Peruru\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'new_file.csv'

# %%
x=d2.columns
l=[]
for i in range(1,len(x)-1):
    l.append(d2[x[i]].value_counts())
for i in l:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ANANYA~1\AppData\Local\Temp/ipykernel_18568/3701763647.py in <module>
# ----> 1 x=d2.columns
#       2 l=[]
#       3 for i in range(1,len(x)-1):
#       4     l.append(d2[x[i]].value_counts())
#       5 for i in l:
#
# NameError: name 'd2' is not defined

# %%
d2=d2[['Time', 'DC Voltage PV1(V)', 'DC Voltage PV2(V)', 'DC Voltage PV3(V)',
       'DC Voltage PV4(V)', 'DC Current1(A)', 'DC Current2(A)',
       'DC Current3(A)', 'DC Current4(A)', 'Total DC Input Power(W)',
       'AC Voltage R/U/A(V)', 'AC Voltage S/V/B(V)', 'AC Voltage T/W/C(V)',
       'AC Current R/U/A(A)', 'AC Current S/V/B(A)', 'AC Current T/W/C(A)',
       'AC Output Total Power (Active)(W)', 'AC Output Frequency R(Hz)',
       'Generation of Last Month (Active)(kWh)',
       'Daily Generation (Active)(kWh)', 'Total Generation (Active)(kWh)',
       'Power Grid Total Apparent Power(VA)',
       'Inverter Temperature(℃)',
       'Generation Yesterday(kWh)']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ANANYA~1\AppData\Local\Temp/ipykernel_18568/1602504364.py in <module>
# ----> 1 d2=d2[['Time', 'DC Voltage PV1(V)', 'DC Voltage PV2(V)', 'DC Voltage PV3(V)',
#       2        'DC Voltage PV4(V)', 'DC Current1(A)', 'DC Current2(A)',
#       3        'DC Current3(A)', 'DC Current4(A)', 'Total DC Input Power(W)',
#       4        'AC Voltage R/U/A(V)', 'AC Voltage S/V/B(V)', 'AC Voltage T/W/C(V)',
#       5        'AC Current R/U/A(A)', 'AC Current S/V/B(A)', 'AC Current T/W/C(A)',
#
# NameError: name 'd2' is not defined

# %%
d.head(10)
# Out:
#                  Time  DC Voltage PV1(V)  DC Voltage PV2(V)  \
# 0 2022-05-02 05:55:00               92.2              165.4
# 1 2022-05-02 06:00:00              200.1              236.2
# 2 2022-05-02 06:05:00              207.8              344.2
# 3 2022-05-02 06:12:00              228.1              596.1
# 4 2022-05-02 06:17:00              240.1              608.1
# 5 2022-05-02 06:22:00              268.1              603.6
# 6 2022-05-02 06:27:00              548.0              611.8
# 7 2022-05-02 06:33:00              616.0              624.0
# 8 2022-05-02 06:38:00              628.1              628.0
# 9 2022-05-02 06:43:00              627.8              635.3
#
#    DC Voltage PV3(V)  DC Voltage PV4(V)  DC Current1(A)  DC Current2(A)  \
# 0               94.8               86.5             0.1             0.1
# 1              200.1              536.4             0.1             0.2
# 2              216.1              536.4             0.1             0.2
# 3              228.0              536.3             0.2             0.3
# 4              240.1              536.6             0.2             0.3
# 5              267.8              252.1             0.2             0.4
# 6              523.9              452.3             0.3             0.5
# 7              632.1              664.1             0.3             0.6
# 8              628.3              660.0             0.4             0.8
# 9              628.1              667.7             0.6             1.0
#
#    DC Current3(A)  DC Current4(A)  Total DC Input Power(W)  ...  \
# 0             0.1             0.1                       43  ...
# 1             0.1             0.1                      140  ...
# 2             0.1             0.1                      164  ...
# 3             0.2             0.2                      377  ...
# 4             0.2             0.2                      385  ...
# 5             0.2             0.2                      399  ...
# 6             0.3             0.3                      763  ...
# 7             0.3             0.3                      948  ...
# 8             0.4             0.4                     1268  ...
# 9             0.6             0.5                     1722  ...
#
#    AC Current S/V/B(A)  AC Current T/W/C(A)  \
# 0                  0.0                  0.0
# 1                  0.1                  0.1
# 2                  0.2                  0.2
# 3                  0.4                  0.4
# 4                  0.5                  0.5
# 5                  0.5                  0.5
# 6                  0.9                  0.9
# 7                  1.4                  1.3
# 8                  1.7                  1.7
# 9                  2.4                  2.3
#
#    AC Output Total Power (Active)(W)  AC Output Frequency R(Hz)  \
# 0                                 20                      50.00
# 1                                 30                      50.10
# 2                                 40                      50.11
# 3                                200                      50.01
# 4                                160                      50.06
# 5                                220                      50.05
# 6                                500                      50.03
# 7                                740                      49.99
# 8                               1080                      50.06
# 9                               1540                      50.01
#
#    Generation of Last Month (Active)(kWh)  Daily Generation (Active)(kWh)  \
# 0                                    3164                             0.0
# 1                                    3164                             0.0
# 2                                    3164                             0.0
# 3                                    3164                             0.0
# 4                                    3164                             0.0
# 5                                    3164                             0.1
# 6                                    3164                             0.1
# 7                                    3164                             0.1
# 8                                    3164                             0.2
# 9                                    3164                             0.3
#
#    Total Generation (Active)(kWh)  Power Grid Total Apparent Power(VA)  \
# 0                        117029.0                                   80
# 1                        117029.0                                   20
# 2                        117029.0                                   30
# 3                        117029.0                                  190
# 4                        117029.0                                  160
# 5                        117029.0                                  240
# 6                        117029.0                                  480
# 7                        117029.0                                  710
# 8                        117029.0                                 1080
# 9                        117029.0                                 1530
#
#    Inverter Temperature(℃)  Generation Yesterday(kWh)
# 0                     32.9                      126.9
# 1                     34.1                      126.9
# 2                     34.4                      126.9
# 3                     34.9                      126.9
# 4                     35.3                      126.9
# 5                     35.4                      126.9
# 6                     35.7                      126.9
# 7                     36.1                      126.9
# 8                     36.5                      126.9
# 9                     36.8                      126.9
#
# [10 rows x 24 columns]

# %%
d2.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ANANYA~1\AppData\Local\Temp/ipykernel_18568/2444197695.py in <module>
# ----> 1 d2.isna().sum()
#
# NameError: name 'd2' is not defined

# %%
d2.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ANANYA~1\AppData\Local\Temp/ipykernel_18568/1417023354.py in <module>
# ----> 1 d2.dtypes
#
# NameError: name 'd2' is not defined

# %%
d2.loc[:,'Time'] = d2['Time'].astype('string')#converted time to string
d2.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ANANYA~1\AppData\Local\Temp/ipykernel_18568/1465657176.py in <module>
# ----> 1 d2.loc[:,'Time'] = d2['Time'].astype('string')#converted time to string
#       2 d2.dtypes
#
# NameError: name 'd2' is not defined

# %%
d2['Time']= pd.to_datetime(d2['Time'])
d2.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ANANYA~1\AppData\Local\Temp/ipykernel_18568/3037916534.py in <module>
# ----> 1 d2['Time']= pd.to_datetime(d2['Time'])
#       2 d2.dtypes
#
# NameError: name 'd2' is not defined

# %%
from datetime import date
dates=d2
s=(dates['Time'].apply(lambda x: x.date()).value_counts() >= 80) 
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ANANYA~1\AppData\Local\Temp/ipykernel_18568/2668563386.py in <module>
#       1 from datetime import date
# ----> 2 dates=d2
#       3 s=(dates['Time'].apply(lambda x: x.date()).value_counts() >= 80)
#       4 s
#
# NameError: name 'd2' is not defined

# %%
#the final dataset is d2. Use d2 from now on.

# %%
import matplotlib.pyplot as plt

# %%
s.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ANANYA~1\AppData\Local\Temp/ipykernel_18568/1029891648.py in <module>
# ----> 1 s.plot()
#       2 plt.show()
#
# c:\Users\Ananya Peruru\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# c:\Users\Ananya Peruru\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# c:\Users\Ananya Peruru\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     284     def generate(self):
#     285         self._args_adjust()
# --> 286         self._compute_plot_data()
#     287         self._setup_subplots()
#     288         self._make_plot()
#
# c:\Users\Ananya Peruru\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     451         # no non-numeric frames or series allowed
#     452         if is_empty:
# --> 453             raise TypeError("no numeric data to plot")
#     454
#     455         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
d.tail(10)
# Out:
#                      Time  DC Voltage PV1(V)  DC Voltage PV2(V)  \
# 23267 2022-10-09 17:27:00              617.5              619.0
# 23268 2022-10-09 17:32:00              613.1              606.6
# 23269 2022-10-09 17:37:00              644.9              599.1
# 23270 2022-10-09 17:43:00              621.2              590.9
# 23271 2022-10-09 17:48:00              576.9              591.0
# 23272 2022-10-09 17:53:00              200.0              546.6
# 23273 2022-10-09 17:58:00              199.9              200.1
# 23274 2022-10-09 18:03:00              457.3              200.0
# 23275 2022-10-09 18:09:00              437.6              420.4
# 23276 2022-10-09 18:14:00              193.3              258.8
#
#        DC Voltage PV3(V)  DC Voltage PV4(V)  DC Current1(A)  DC Current2(A)  \
# 23267              621.9              670.4             0.4             0.7
# 23268              625.5              658.1             0.3             0.6
# 23269              609.8              658.3             0.2             0.5
# 23270              593.7              650.9             0.1             0.3
# 23271              233.6              274.3             0.1             0.2
# 23272              200.0              200.0             0.1             0.1
# 23273              476.1              509.6             0.1             0.1
# 23274              476.3              509.6             0.1             0.1
# 23275              382.1              389.7             0.1             0.1
# 23276              184.9              188.8             0.1             0.1
#
#        DC Current3(A)  DC Current4(A)  Total DC Input Power(W)  ...  \
# 23267             0.3             0.3                     1067  ...
# 23268             0.3             0.3                      932  ...
# 23269             0.2             0.2                      682  ...
# 23270             0.1             0.1                      363  ...
# 23271             0.1             0.1                      226  ...
# 23272             0.1             0.1                      114  ...
# 23273             0.1             0.1                      138  ...
# 23274             0.1             0.1                      164  ...
# 23275             0.1             0.1                      162  ...
# 23276             0.1             0.1                       82  ...
#
#        AC Current S/V/B(A)  AC Current T/W/C(A)  \
# 23267                  1.6                  1.5
# 23268                  1.5                  1.4
# 23269                  0.8                  0.8
# 23270                  0.5                  0.5
# 23271                  0.2                  0.2
# 23272                  0.1                  0.1
# 23273                  0.0                  0.0
# 23274                  0.0                  0.0
# 23275                  0.0                  0.0
# 23276                  0.0                  0.0
#
#        AC Output Total Power (Active)(W)  AC Output Frequency R(Hz)  \
# 23267                                970                      50.01
# 23268                                730                      50.08
# 23269                                430                      49.95
# 23270                                250                      49.94
# 23271                                 30                      50.05
# 23272                                 20                      49.99
# 23273                                 20                      50.03
# 23274                                 20                      50.06
# 23275                                 20                      49.96
# 23276                                 20                      50.03
#
#        Generation of Last Month (Active)(kWh)  Daily Generation (Active)(kWh)  \
# 23267                                    2835                            82.2
# 23268                                    2835                            82.3
# 23269                                    2835                            82.4
# 23270                                    2835                            82.4
# 23271                                    2835                            82.4
# 23272                                    2835                            82.4
# 23273                                    2835                            82.4
# 23274                                    2835                            82.4
# 23275                                    2835                            82.4
# 23276                                    2835                            82.4
#
#        Total Generation (Active)(kWh)  Power Grid Total Apparent Power(VA)  \
# 23267                        133462.0                                  800
# 23268                        133462.0                                  720
# 23269                        133462.0                                  450
# 23270                        133462.0                                  240
# 23271                        133462.0                                   10
# 23272                        133462.0                                   80
# 23273                        133462.0                                   70
# 23274                        133462.0                                  140
# 23275                        133462.0                                  140
# 23276                        133462.0                                  130
#
#        Inverter Temperature(℃)  Generation Yesterday(kWh)
# 23267                     39.2                      131.9
# 23268                     38.7                      131.9
# 23269                     38.4                      131.9
# 23270                     38.2                      131.9
# 23271                     38.0                      131.9
# 23272                     37.8                      131.9
# 23273                     37.6                      131.9
# 23274                     37.4                      131.9
# 23275                     37.1                      131.9
# 23276                     36.8                      131.9
#
# [10 rows x 24 columns]

# %% [markdown]
# # Converting to 1 HR intervals

# %%
d.set_index('Time',inplace= True)

# %%
df=d
df=df.resample("1H").mean()
df
# Out:
#                      DC Voltage PV1(V)  DC Voltage PV2(V)  DC Voltage PV3(V)  \
# Time
# 2022-05-02 05:00:00          92.200000         165.400000          94.800000
# 2022-05-02 06:00:00         455.016667         568.625000         455.058333
# 2022-05-02 07:00:00         637.527273         645.463636         608.336364
# 2022-05-02 08:00:00         625.583333         625.608333         621.641667
# 2022-05-02 09:00:00         604.027273         608.400000         606.981818
# ...                                ...                ...                ...
# 2022-10-09 14:00:00         731.608333         729.033333         732.191667
# 2022-10-09 15:00:00         652.225000         658.508333         663.175000
# 2022-10-09 16:00:00         616.900000         634.436364         636.845455
# 2022-10-09 17:00:00         552.183333         577.425000         537.316667
# 2022-10-09 18:00:00         362.733333         293.066667         347.766667
#
#                      DC Voltage PV4(V)  DC Current1(A)  DC Current2(A)  \
# Time
# 2022-05-02 05:00:00          86.500000        0.100000        0.100000
# 2022-05-02 06:00:00         572.833333        0.416667        0.733333
# 2022-05-02 07:00:00         672.427273        1.654545        2.781818
# 2022-05-02 08:00:00         661.633333        3.300000        6.375000
# 2022-05-02 09:00:00         639.736364        4.763636        9.354545
# ...                                ...             ...             ...
# 2022-10-09 14:00:00         767.866667        0.000000        0.000000
# 2022-10-09 15:00:00         693.491667        3.175000        5.908333
# 2022-10-09 16:00:00         673.309091        1.772727        3.418182
# 2022-10-09 17:00:00         581.341667        0.400000        0.741667
# 2022-10-09 18:00:00         362.700000        0.100000        0.100000
#
#                      DC Current3(A)  DC Current4(A)  Total DC Input Power(W)  \
# Time
# 2022-05-02 05:00:00        0.100000        0.100000                43.000000
# 2022-05-02 06:00:00        0.408333        0.408333              1171.583333
# 2022-05-02 07:00:00        1.590909        1.581818              4868.545455
# 2022-05-02 08:00:00        3.308333        3.250000             10230.333333
# 2022-05-02 09:00:00        4.754545        4.709091             14452.090909
# ...                             ...             ...                      ...
# 2022-10-09 14:00:00        0.000000        0.000000                 0.000000
# 2022-10-09 15:00:00        3.066667        3.066667              9512.666667
# 2022-10-09 16:00:00        1.672727        1.690909              5404.000000
# 2022-10-09 17:00:00        0.383333        0.366667              1171.833333
# 2022-10-09 18:00:00        0.100000        0.100000               136.000000
#
#                      AC Voltage R/U/A(V)  ...  AC Current S/V/B(A)  \
# Time                                      ...
# 2022-05-02 05:00:00           236.800000  ...             0.000000
# 2022-05-02 06:00:00           235.258333  ...             1.516667
# 2022-05-02 07:00:00           234.718182  ...             6.572727
# 2022-05-02 08:00:00           236.733333  ...            13.841667
# 2022-05-02 09:00:00           233.936364  ...            19.909091
# ...                                  ...  ...                  ...
# 2022-10-09 14:00:00             0.000000  ...             0.000000
# 2022-10-09 15:00:00           175.350000  ...            11.633333
# 2022-10-09 16:00:00           255.236364  ...             6.745455
# 2022-10-09 17:00:00           249.091667  ...             1.525000
# 2022-10-09 18:00:00           244.833333  ...             0.000000
#
#                      AC Current T/W/C(A)  AC Output Total Power (Active)(W)  \
# Time
# 2022-05-02 05:00:00             0.000000                          20.000000
# 2022-05-02 06:00:00             1.516667                         974.166667
# 2022-05-02 07:00:00             6.545455                        4662.727273
# 2022-05-02 08:00:00            13.866667                        9886.666667
# 2022-05-02 09:00:00            19.745455                       13979.090909
# ...                                  ...                                ...
# 2022-10-09 14:00:00             0.000000                           0.000000
# 2022-10-09 15:00:00            11.600000                        9235.000000
# 2022-10-09 16:00:00             6.727273                        5179.090909
# 2022-10-09 17:00:00             1.491667                        1008.333333
# 2022-10-09 18:00:00             0.000000                          20.000000
#
#                      AC Output Frequency R(Hz)  \
# Time
# 2022-05-02 05:00:00                  50.000000
# 2022-05-02 06:00:00                  50.042500
# 2022-05-02 07:00:00                  50.061818
# 2022-05-02 08:00:00                  50.080000
# 2022-05-02 09:00:00                  50.028182
# ...                                        ...
# 2022-10-09 14:00:00                   0.000000
# 2022-10-09 15:00:00                  33.358333
# 2022-10-09 16:00:00                  49.995455
# 2022-10-09 17:00:00                  50.011667
# 2022-10-09 18:00:00                  50.016667
#
#                      Generation of Last Month (Active)(kWh)  \
# Time
# 2022-05-02 05:00:00                                  3164.0
# 2022-05-02 06:00:00                                  3164.0
# 2022-05-02 07:00:00                                  3164.0
# 2022-05-02 08:00:00                                  3164.0
# 2022-05-02 09:00:00                                  3164.0
# ...                                                     ...
# 2022-10-09 14:00:00                                  2835.0
# 2022-10-09 15:00:00                                  2835.0
# 2022-10-09 16:00:00                                  2835.0
# 2022-10-09 17:00:00                                  2835.0
# 2022-10-09 18:00:00                                  2835.0
#
#                      Daily Generation (Active)(kWh)  \
# Time
# 2022-05-02 05:00:00                        0.000000
# 2022-05-02 06:00:00                        0.241667
# 2022-05-02 07:00:00                        2.954545
# 2022-05-02 08:00:00                       10.008333
# 2022-05-02 09:00:00                       22.709091
# ...                                             ...
# 2022-10-09 14:00:00                       67.000000
# 2022-10-09 15:00:00                       70.283333
# 2022-10-09 16:00:00                       79.563636
# 2022-10-09 17:00:00                       82.141667
# 2022-10-09 18:00:00                       82.400000
#
#                      Total Generation (Active)(kWh)  \
# Time
# 2022-05-02 05:00:00                   117029.000000
# 2022-05-02 06:00:00                   117029.250000
# 2022-05-02 07:00:00                   117031.909091
# 2022-05-02 08:00:00                   117039.000000
# 2022-05-02 09:00:00                   117051.727273
# ...                                             ...
# 2022-10-09 14:00:00                   133446.000000
# 2022-10-09 15:00:00                   133449.416667
# 2022-10-09 16:00:00                   133458.909091
# 2022-10-09 17:00:00                   133461.666667
# 2022-10-09 18:00:00                   133462.000000
#
#                      Power Grid Total Apparent Power(VA)  \
# Time
# 2022-05-02 05:00:00                            80.000000
# 2022-05-02 06:00:00                           966.666667
# 2022-05-02 07:00:00                          4650.000000
# 2022-05-02 08:00:00                          9890.000000
# 2022-05-02 09:00:00                         13969.090909
# ...                                                  ...
# 2022-10-09 14:00:00                             0.000000
# 2022-10-09 15:00:00                          9236.666667
# 2022-10-09 16:00:00                          4351.818182
# 2022-10-09 17:00:00                          1000.000000
# 2022-10-09 18:00:00                           136.666667
#
#                      Inverter Temperature(℃)  Generation Yesterday(kWh)
# Time
# 2022-05-02 05:00:00                32.900000                      126.9
# 2022-05-02 06:00:00                36.025000                      126.9
# 2022-05-02 07:00:00                41.400000                      126.9
# 2022-05-02 08:00:00                48.441667                      126.9
# 2022-05-02 09:00:00                56.872727                      126.9
# ...                                      ...                        ...
# 2022-10-09 14:00:00                38.358333                      131.9
# 2022-10-09 15:00:00                42.691667                      131.9
# 2022-10-09 16:00:00                44.054545                      131.9
# 2022-10-09 17:00:00                39.266667                      131.9
# 2022-10-09 18:00:00                37.100000                      131.9
#
# [3854 rows x 23 columns]

# %%
times=df.reset_index()
times
# Out:
#                     Time  DC Voltage PV1(V)  DC Voltage PV2(V)  \
# 0    2022-05-02 05:00:00          92.200000         165.400000
# 1    2022-05-02 06:00:00         455.016667         568.625000
# 2    2022-05-02 07:00:00         637.527273         645.463636
# 3    2022-05-02 08:00:00         625.583333         625.608333
# 4    2022-05-02 09:00:00         604.027273         608.400000
# ...                  ...                ...                ...
# 3849 2022-10-09 14:00:00         731.608333         729.033333
# 3850 2022-10-09 15:00:00         652.225000         658.508333
# 3851 2022-10-09 16:00:00         616.900000         634.436364
# 3852 2022-10-09 17:00:00         552.183333         577.425000
# 3853 2022-10-09 18:00:00         362.733333         293.066667
#
#       DC Voltage PV3(V)  DC Voltage PV4(V)  DC Current1(A)  DC Current2(A)  \
# 0             94.800000          86.500000        0.100000        0.100000
# 1            455.058333         572.833333        0.416667        0.733333
# 2            608.336364         672.427273        1.654545        2.781818
# 3            621.641667         661.633333        3.300000        6.375000
# 4            606.981818         639.736364        4.763636        9.354545
# ...                 ...                ...             ...             ...
# 3849         732.191667         767.866667        0.000000        0.000000
# 3850         663.175000         693.491667        3.175000        5.908333
# 3851         636.845455         673.309091        1.772727        3.418182
# 3852         537.316667         581.341667        0.400000        0.741667
# 3853         347.766667         362.700000        0.100000        0.100000
#
#       DC Current3(A)  DC Current4(A)  Total DC Input Power(W)  ...  \
# 0           0.100000        0.100000                43.000000  ...
# 1           0.408333        0.408333              1171.583333  ...
# 2           1.590909        1.581818              4868.545455  ...
# 3           3.308333        3.250000             10230.333333  ...
# 4           4.754545        4.709091             14452.090909  ...
# ...              ...             ...                      ...  ...
# 3849        0.000000        0.000000                 0.000000  ...
# 3850        3.066667        3.066667              9512.666667  ...
# 3851        1.672727        1.690909              5404.000000  ...
# 3852        0.383333        0.366667              1171.833333  ...
# 3853        0.100000        0.100000               136.000000  ...
#
#       AC Current S/V/B(A)  AC Current T/W/C(A)  \
# 0                0.000000             0.000000
# 1                1.516667             1.516667
# 2                6.572727             6.545455
# 3               13.841667            13.866667
# 4               19.909091            19.745455
# ...                   ...                  ...
# 3849             0.000000             0.000000
# 3850            11.633333            11.600000
# 3851             6.745455             6.727273
# 3852             1.525000             1.491667
# 3853             0.000000             0.000000
#
#       AC Output Total Power (Active)(W)  AC Output Frequency R(Hz)  \
# 0                             20.000000                  50.000000
# 1                            974.166667                  50.042500
# 2                           4662.727273                  50.061818
# 3                           9886.666667                  50.080000
# 4                          13979.090909                  50.028182
# ...                                 ...                        ...
# 3849                           0.000000                   0.000000
# 3850                        9235.000000                  33.358333
# 3851                        5179.090909                  49.995455
# 3852                        1008.333333                  50.011667
# 3853                          20.000000                  50.016667
#
#       Generation of Last Month (Active)(kWh)  Daily Generation (Active)(kWh)  \
# 0                                     3164.0                        0.000000
# 1                                     3164.0                        0.241667
# 2                                     3164.0                        2.954545
# 3                                     3164.0                       10.008333
# 4                                     3164.0                       22.709091
# ...                                      ...                             ...
# 3849                                  2835.0                       67.000000
# 3850                                  2835.0                       70.283333
# 3851                                  2835.0                       79.563636
# 3852                                  2835.0                       82.141667
# 3853                                  2835.0                       82.400000
#
#       Total Generation (Active)(kWh)  Power Grid Total Apparent Power(VA)  \
# 0                      117029.000000                            80.000000
# 1                      117029.250000                           966.666667
# 2                      117031.909091                          4650.000000
# 3                      117039.000000                          9890.000000
# 4                      117051.727273                         13969.090909
# ...                              ...                                  ...
# 3849                   133446.000000                             0.000000
# 3850                   133449.416667                          9236.666667
# 3851                   133458.909091                          4351.818182
# 3852                   133461.666667                          1000.000000
# 3853                   133462.000000                           136.666667
#
#       Inverter Temperature(℃)  Generation Yesterday(kWh)
# 0                   32.900000                      126.9
# 1                   36.025000                      126.9
# 2                   41.400000                      126.9
# 3                   48.441667                      126.9
# 4                   56.872727                      126.9
# ...                       ...                        ...
# 3849                38.358333                      131.9
# 3850                42.691667                      131.9
# 3851                44.054545                      131.9
# 3852                39.266667                      131.9
# 3853                37.100000                      131.9
#
# [3854 rows x 24 columns]

# %%
#from datetime import date,datetime,time

# %%
times['actual time']=times['Time'].apply(lambda x: x.time())
times[times['actual time']==time(6,00,00)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ANANYA~1\AppData\Local\Temp/ipykernel_18568/3812691787.py in <module>
#       1 times['actual time']=times['Time'].apply(lambda x: x.time())
# ----> 2 times[times['actual time']==time(6,00,00)]
#
# NameError: name 'time' is not defined

# %%
w=pd.read_csv("weather_may_to_oct9.csv")
w
# Out:
#                   name             datetime  temp  feelslike   dew  humidity  \
# 0     17.4116, 78.3987  2022-05-02T00:00:00  88.7       89.4  62.6     41.86
# 1     17.4116, 78.3987  2022-05-02T01:00:00  86.0       87.1  63.5     47.07
# 2     17.4116, 78.3987  2022-05-02T02:00:00  87.4       90.1  66.5     50.00
# 3     17.4116, 78.3987  2022-05-02T03:00:00  84.2       86.1  65.3     53.10
# 4     17.4116, 78.3987  2022-05-02T04:00:00  84.2       85.0  62.6     48.35
# ...                ...                  ...   ...        ...   ...       ...
# 3860  17.4116, 78.3987  2021-10-09T20:00:00  74.1       74.1  72.1     93.25
# 3861  17.4116, 78.3987  2021-10-09T21:00:00  72.7       72.7  70.3     92.42
# 3862  17.4116, 78.3987  2021-10-09T22:00:00  78.8       78.8  75.2     88.76
# 3863  17.4116, 78.3987  2021-10-09T23:00:00  74.7       74.7  73.2     94.94
# 3864                                   NaN   NaN        NaN   NaN       NaN
#
#       precip  precipprob preciptype  snow  ...  sealevelpressure  cloudcover  \
# 0       0.00         0.0        NaN   0.0  ...            1008.0        50.0
# 1       0.00         0.0        NaN   0.0  ...            1008.0        50.0
# 2       0.00         0.0        NaN   0.0  ...            1003.4        80.4
# 3       0.00         0.0        NaN   0.0  ...            1007.0        50.0
# 4       0.00         0.0        NaN   0.0  ...            1007.0        50.0
# ...      ...         ...        ...   ...  ...               ...         ...
# 3860    2.52       100.0       rain   0.0  ...            1010.9        93.8
# 3861    0.00         0.0        NaN   0.0  ...            1013.0        98.4
# 3862    0.00         0.0        NaN   0.0  ...            1014.0        89.0
# 3863    0.00         0.0        NaN   0.0  ...            1009.2        89.8
# 3864     NaN         NaN        NaN   NaN  ...               NaN         NaN
#
#       visibility  solarradiation  solarenergy  uvindex  severerisk  \
# 0            3.1             0.0          NaN      0.0        10.0
# 1            3.1             0.0          NaN      0.0        10.0
# 2            5.5             0.0          NaN      0.0        10.0
# 3            3.1             0.0          NaN      0.0        60.0
# 4            3.1             0.0          NaN      0.0        60.0
# ...          ...             ...          ...      ...         ...
# 3860         2.2             0.0          NaN      0.0         NaN
# 3861         1.9             0.0          NaN      0.0         NaN
# 3862         2.5             0.0          NaN      0.0         NaN
# 3863         2.5             0.0          NaN      0.0         NaN
# 3864         NaN             NaN          NaN      NaN         NaN
#
#             conditions                 icon                           stations
# 0     Partially cloudy  partly-cloudy-night                   43128599999,VOHS
# 1     Partially cloudy  partly-cloudy-night                   43128599999,VOHS
# 2     Partially cloudy  partly-cloudy-night       43128599999,43128099999,VOHS
# 3     Partially cloudy  partly-cloudy-night                   43128599999,VOHS
# 4     Partially cloudy  partly-cloudy-night                   43128599999,VOHS
# ...                ...                  ...                                ...
# 3860    Rain, Overcast                 rain  VOHY,43128599999,43128099999,VOHS
# 3861          Overcast               cloudy  VOHY,43128599999,43128099999,VOHS
# 3862  Partially cloudy  partly-cloudy-night                   43128599999,VOHS
# 3863  Partially cloudy  partly-cloudy-night       43128599999,43128099999,VOHS
# 3864               NaN                  NaN                                NaN
#
# [3865 rows x 24 columns]

# %%
#combine weather and solar data
