# %% [markdown]
# # Basic data exploration

# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_csv("may-october(5 min).csv")
d
# Out:
#                    Time       InverterSN  Data LoggerSN Alert Details  \
# 0      2022/05/02 05:55  110470185160082      706238511           NaN
# 1      2022/05/02 06:00  110470185160082      706238511           NaN
# 2      2022/05/02 06:05  110470185160082      706238511           NaN
# 3      2022/05/02 06:12  110470185160082      706238511           NaN
# 4      2022/05/02 06:17  110470185160082      706238511           NaN
# ...                 ...              ...            ...           ...
# 23272  2022/10/09 17:53  110470185160082      706238511           NaN
# 23273  2022/10/09 17:58  110470185160082      706238511           NaN
# 23274  2022/10/09 18:03  110470185160082      706238511           NaN
# 23275  2022/10/09 18:09  110470185160082      706238511           NaN
# 23276  2022/10/09 18:14  110470185160082      706238511           NaN
#
#       Alert Code  DC Voltage PV1(V)  DC Voltage PV2(V)  DC Voltage PV3(V)  \
# 0            NaN               92.2              165.4               94.8
# 1            NaN              200.1              236.2              200.1
# 2            NaN              207.8              344.2              216.1
# 3            NaN              228.1              596.1              228.0
# 4            NaN              240.1              608.1              240.1
# ...          ...                ...                ...                ...
# 23272        NaN              200.0              546.6              200.0
# 23273        NaN              199.9              200.1              476.1
# 23274        NaN              457.3              200.0              476.3
# 23275        NaN              437.6              420.4              382.1
# 23276        NaN              193.3              258.8              184.9
#
#        DC Voltage PV4(V)  DC Current1(A)  ...  AC Output Frequency R(Hz)  \
# 0                   86.5             0.1  ...                      50.00
# 1                  536.4             0.1  ...                      50.10
# 2                  536.4             0.1  ...                      50.11
# 3                  536.3             0.2  ...                      50.01
# 4                  536.6             0.2  ...                      50.06
# ...                  ...             ...  ...                        ...
# 23272              200.0             0.1  ...                      49.99
# 23273              509.6             0.1  ...                      50.03
# 23274              509.6             0.1  ...                      50.06
# 23275              389.7             0.1  ...                      49.96
# 23276              188.8             0.1  ...                      50.03
#
#        Generation of Last Month (Active)(kWh)  Daily Generation (Active)(kWh)  \
# 0                                        3164                             0.0
# 1                                        3164                             0.0
# 2                                        3164                             0.0
# 3                                        3164                             0.0
# 4                                        3164                             0.0
# ...                                       ...                             ...
# 23272                                    2835                            82.4
# 23273                                    2835                            82.4
# 23274                                    2835                            82.4
# 23275                                    2835                            82.4
# 23276                                    2835                            82.4
#
#        Total Generation (Active)(kWh)  Power Grid Total Apparent Power(VA)  \
# 0                            117029.0                                   80
# 1                            117029.0                                   20
# 2                            117029.0                                   30
# 3                            117029.0                                  190
# 4                            117029.0                                  160
# ...                               ...                                  ...
# 23272                        133462.0                                   80
# 23273                        133462.0                                   70
# 23274                        133462.0                                  140
# 23275                        133462.0                                  140
# 23276                        133462.0                                  130
#
#        Grid Power Factor  Inverter Temperature(℃)  Inverter Status  \
# 0                    1.0                     32.9             1022
# 1                    1.0                     34.1             1022
# 2                    1.0                     34.4             1022
# 3                    1.0                     34.9             1022
# 4                    1.0                     35.3             1022
# ...                  ...                      ...              ...
# 23272                1.0                     37.8             1022
# 23273                1.0                     37.6             1022
# 23274                1.0                     37.4             1022
# 23275                1.0                     37.1             1022
# 23276                1.0                     36.8             1022
#
#        Generation Yesterday(kWh)       System Time
# 0                          126.9     22-5-2 6:16:1
# 1                          126.9    22-5-2 6:21:39
# 2                          126.9    22-5-2 6:26:12
# 3                          126.9    22-5-2 6:33:15
# 4                          126.9    22-5-2 6:38:44
# ...                          ...               ...
# 23272                      131.9  22-10-9 18:22:15
# 23273                      131.9  22-10-9 18:26:40
# 23274                      131.9  22-10-9 18:32:14
# 23275                      131.9  22-10-9 18:37:44
# 23276                      131.9  22-10-9 18:43:15
#
# [23277 rows x 31 columns]

# %%
d[d['Alert Details'].notna()]
# Out:
#                    Time       InverterSN  Data LoggerSN Alert Details  \
# 108    2022/05/02 15:00  110470185160082      706238511             N
# 143    2022/05/02 18:00  110470185160082      706238511             N
# 147    2022/05/02 18:09  110470185160082      706238511             N
# 148    2022/05/02 18:09  110470185160082      706238511             N
# 314    2022/05/04 06:34  110470185160082      706238511             N
# ...                 ...              ...            ...           ...
# 23238  2022/10/09 14:54  110470185160082      706238511             N
# 23239  2022/10/09 15:00  110470185160082      706238511             N
# 23240  2022/10/09 15:05  110470185160082      706238511             N
# 23241  2022/10/09 15:10  110470185160082      706238511             N
# 23242  2022/10/09 15:15  110470185160082      706238511             N
#
#       Alert Code  DC Voltage PV1(V)  DC Voltage PV2(V)  DC Voltage PV3(V)  \
# 108        1015H              726.5              725.5              727.8
# 143        1015H              675.1              673.9              675.9
# 147        1015H              666.3              665.1              667.1
# 148        1015H              666.3              665.1              667.1
# 314        1015H              649.1              647.8              650.4
# ...          ...                ...                ...                ...
# 23238      1015H              699.1              695.6              699.4
# 23239      1015H              744.3              743.3              748.0
# 23240      1015H              738.8              737.7              743.1
# 23241      1015H              726.4              725.9              732.0
# 23242      1015H              734.9              734.6              740.9
#
#        DC Voltage PV4(V)  DC Current1(A)  ...  AC Output Frequency R(Hz)  \
# 108                761.9             0.0  ...                      50.03
# 143                704.4             0.0  ...                      50.37
# 147                693.7             0.0  ...                      49.96
# 148                693.7             0.0  ...                      49.96
# 314                646.5             0.0  ...                      50.01
# ...                  ...             ...  ...                        ...
# 23238              733.5             0.0  ...                       0.00
# 23239              784.1             0.0  ...                       0.00
# 23240              778.6             0.0  ...                       0.00
# 23241              767.0             0.0  ...                       0.00
# 23242              777.9             0.0  ...                       0.00
#
#        Generation of Last Month (Active)(kWh)  Daily Generation (Active)(kWh)  \
# 108                                      3164                           114.9
# 143                                      3164                           130.6
# 147                                      3164                           130.7
# 148                                      3164                           130.7
# 314                                      3164                             0.0
# ...                                       ...                             ...
# 23238                                    2835                            67.0
# 23239                                    2835                            67.0
# 23240                                    2835                            67.0
# 23241                                    2835                            67.0
# 23242                                    2835                            67.0
#
#        Total Generation (Active)(kWh)  Power Grid Total Apparent Power(VA)  \
# 108                          117144.0                                    0
# 143                          117160.0                                    0
# 147                          117160.0                                    0
# 148                          117160.0                                    0
# 314                          117291.0                                    0
# ...                               ...                                  ...
# 23238                        133446.0                                    0
# 23239                        133446.0                                    0
# 23240                        133446.0                                    0
# 23241                        133446.0                                    0
# 23242                        133446.0                                    0
#
#        Grid Power Factor  Inverter Temperature(℃)  Inverter Status  \
# 108                  1.0                     65.1             1025
# 143                  1.0                     47.7             1025
# 147                  1.0                     47.7             1025
# 148                  1.0                     47.7             1025
# 314                  1.0                     24.7             1025
# ...                  ...                      ...              ...
# 23238                1.0                     35.9             1025
# 23239                1.0                     35.7             1025
# 23240                1.0                     35.5             1025
# 23241                1.0                     35.3             1025
# 23242                1.0                     35.1             1025
#
#        Generation Yesterday(kWh)       System Time
# 108                        126.9   22-5-2 15:22:12
# 143                        126.9   22-5-2 18:21:17
# 147                        126.9   22-5-2 18:30:37
# 148                        126.9   22-5-2 18:30:37
# 314                        131.2     22-5-4 6:56:0
# ...                          ...               ...
# 23238                      131.9   22-10-9 15:23:4
# 23239                      131.9  22-10-9 15:28:35
# 23240                      131.9   22-10-9 15:34:6
# 23241                      131.9  22-10-9 15:38:31
# 23242                      131.9   22-10-9 15:44:8
#
# [415 rows x 31 columns]

# %%
d.columns
# Out:
# Index(['Time', 'InverterSN', 'Data LoggerSN', 'Alert Details', 'Alert Code',
#        'DC Voltage PV1(V)', 'DC Voltage PV2(V)', 'DC Voltage PV3(V)',
#        'DC Voltage PV4(V)', 'DC Current1(A)', 'DC Current2(A)',
#        'DC Current3(A)', 'DC Current4(A)', 'Total DC Input Power(W)',
#        'AC Voltage R/U/A(V)', 'AC Voltage S/V/B(V)', 'AC Voltage T/W/C(V)',
#        'AC Current R/U/A(A)', 'AC Current S/V/B(A)', 'AC Current T/W/C(A)',
#        'AC Output Total Power (Active)(W)', 'AC Output Frequency R(Hz)',
#        'Generation of Last Month (Active)(kWh)',
#        'Daily Generation (Active)(kWh)', 'Total Generation (Active)(kWh)',
#        'Power Grid Total Apparent Power(VA)', 'Grid Power Factor',
#        'Inverter Temperature(℃)', 'Inverter Status',
#        'Generation Yesterday(kWh)', 'System Time'],
#       dtype='object')

# %%
d['InverterSN'].unique
# Out:
# <bound method Series.unique of 0        110470185160082
# 1        110470185160082
# 2        110470185160082
# 3        110470185160082
# 4        110470185160082
#               ...
# 23272    110470185160082
# 23273    110470185160082
# 23274    110470185160082
# 23275    110470185160082
# 23276    110470185160082
# Name: InverterSN, Length: 23277, dtype: int64>

# %%
d['InverterSN'].value_counts()
# Out:
# 110470185160082    23277
# Name: InverterSN, dtype: int64

# %%
d['Data LoggerSN'].unique
# Out:
# <bound method Series.unique of 0        706238511
# 1        706238511
# 2        706238511
# 3        706238511
# 4        706238511
#            ...
# 23272    706238511
# 23273    706238511
# 23274    706238511
# 23275    706238511
# 23276    706238511
# Name: Data LoggerSN, Length: 23277, dtype: int64>

# %%
d['Data LoggerSN'].value_counts()
# Out:
# 706238511    23277
# Name: Data LoggerSN, dtype: int64

# %%
d['Inverter Status'].unique
# Out:
# <bound method Series.unique of 0        1022
# 1        1022
# 2        1022
# 3        1022
# 4        1022
#          ...
# 23272    1022
# 23273    1022
# 23274    1022
# 23275    1022
# 23276    1022
# Name: Inverter Status, Length: 23277, dtype: object>

# %%
d['Inverter Status'].value_counts()
# Out:
# 1022       22835
# 1025         415
# Standby       27
# Name: Inverter Status, dtype: int64

# %%
d.shape
# Out:
# (23277, 31)

# %%
d.dtypes
# Out:
# Time                                       object
# InverterSN                                  int64
# Data LoggerSN                               int64
# Alert Details                              object
# Alert Code                                 object
# DC Voltage PV1(V)                         float64
# DC Voltage PV2(V)                         float64
# DC Voltage PV3(V)                         float64
# DC Voltage PV4(V)                         float64
# DC Current1(A)                            float64
# DC Current2(A)                            float64
# DC Current3(A)                            float64
# DC Current4(A)                            float64
# Total DC Input Power(W)                     int64
# AC Voltage R/U/A(V)                       float64
# AC Voltage S/V/B(V)                       float64
# AC Voltage T/W/C(V)                       float64
# AC Current R/U/A(A)                       float64
# AC Current S/V/B(A)                       float64
# AC Current T/W/C(A)                       float64
# AC Output Total Power (Active)(W)           int64
# AC Output Frequency R(Hz)                 float64
# Generation of Last Month (Active)(kWh)      int64
# Daily Generation (Active)(kWh)            float64
# Total Generation (Active)(kWh)            float64
# Power Grid Total Apparent Power(VA)         int64
# Grid Power Factor                         float64
# Inverter Temperature(℃)                   float64
# Inverter Status                            object
# Generation Yesterday(kWh)                 float64
# System Time                                object
# dtype: object

# %%
x=d.columns
l=[]
for i in range(1,len(x)-1):
    l.append(d[x[i]].value_counts())
for i in l:
    print(i)
# Out:
# 110470185160082    23277
# Name: InverterSN, dtype: int64
# 706238511    23277
# Name: Data LoggerSN, dtype: int64
# N    329
# G     86
# Name: Alert Details, dtype: int64
# 1015H    329
# 1012H     78
# 1010H      5
# 1011H      3
# Name: Alert Code, dtype: int64
# 200.1    142
# 632.1    119
# 200.0    119
# 640.1    117
# 624.0    116
#         ...
# 305.5      1
# 732.8      1
# 135.4      1
# 285.4      1
# 193.3      1
# Name: DC Voltage PV1(V), Length: 2456, dtype: int64
# 200.1    116
# 200.0    101
# 616.1     86
# 612.1     82
# 643.9     82
#         ...
# 549.3      1
# 394.3      1
# 163.6      1
# 207.4      1
# 258.8      1
# Name: DC Voltage PV2(V), Length: 2355, dtype: int64
# 200.1    154
# 200.0    148
# 620.0    118
# 636.1    115
# 632.1    112
#         ...
# 454.9      1
# 505.7      1
# 506.0      1
# 506.3      1
# 184.9      1
# Name: DC Voltage PV3(V), Length: 2582, dtype: int64
# 200.0    173
# 671.9    130
# 672.1    129
# 200.1    129
# 672.0    127
#         ...
# 146.2      1
# 243.1      1
# 405.5      1
# 504.7      1
# 188.8      1
# Name: DC Voltage PV4(V), Length: 2589, dtype: int64
# 0.1     1876
# 0.2      912
# 0.3      765
# 0.4      629
# 0.7      580
#         ...
# 10.0       2
# 10.5       2
# 10.3       1
# 10.9       1
# 11.6       1
# Name: DC Current1(A), Length: 107, dtype: int64
# 0.1     1190
# 0.2      632
# 0.3      505
# 0.0      428
# 0.4      411
#         ...
# 17.7      15
# 17.3      13
# 17.9      10
# 18.1       6
# 18.4       1
# Name: DC Current2(A), Length: 183, dtype: int64
# 0.1     1938
# 0.2      940
# 0.3      754
# 0.4      631
# 0.5      617
#         ...
# 11.3       1
# 11.1       1
# 11.2       1
# 10.1       1
# 10.2       1
# Name: DC Current3(A), Length: 110, dtype: int64
# 0.1     2032
# 0.2      836
# 0.3      810
# 0.4      683
# 0.5      590
#         ...
# 11.1       1
# 10.3       1
# 10.9       1
# 11.4       1
# 10.7       1
# Name: DC Current4(A), Length: 109, dtype: int64
# 0        428
# 80        67
# 169       34
# 166       33
# 139       32
#         ...
# 11159      1
# 6328       1
# 16150      1
# 17382      1
# 1764       1
# Name: Total DC Input Power(W), Length: 13181, dtype: int64
# 234.6    403
# 235.8    402
# 235.5    399
# 236.2    380
# 233.9    379
#         ...
# 200.3      1
# 201.2      1
# 202.5      1
# 196.5      1
# 268.2      1
# Name: AC Voltage R/U/A(V), Length: 218, dtype: int64
# 237.7    411
# 237.4    400
# 237.1    397
# 236.2    396
# 236.5    394
#         ...
# 203.1      1
# 204.1      1
# 202.2      1
# 203.5      1
# 268.5      1
# Name: AC Voltage S/V/B(V), Length: 209, dtype: int64
# 239.0    402
# 235.8    400
# 237.1    396
# 238.7    392
# 236.8    389
#         ...
# 199.0      1
# 206.6      1
# 201.6      1
# 186.9      1
# 200.0      1
# Name: AC Voltage T/W/C(V), Length: 210, dtype: int64
# 0.0     1245
# 0.1      500
# 0.2      272
# 0.4      256
# 1.7      231
#         ...
# 37.1       1
# 40.6       1
# 42.5       1
# 38.0       1
# 39.3       1
# Name: AC Current R/U/A(A), Length: 403, dtype: int64
# 0.0     1245
# 0.1      500
# 0.2      272
# 0.4      256
# 1.5      253
#         ...
# 36.0       1
# 38.4       1
# 39.9       1
# 40.1       1
# 39.7       1
# Name: AC Current S/V/B(A), Length: 399, dtype: int64
# 0.0     1245
# 0.1      500
# 0.2      272
# 0.4      256
# 1.9      221
#         ...
# 39.1       1
# 40.0       1
# 37.7       1
# 39.4       1
# 41.8       1
# Name: AC Current T/W/C(A), Length: 399, dtype: int64
# 20       1443
# 0         428
# 160        66
# 210        65
# 100        62
#          ...
# 26100       1
# 25250       1
# 15710       1
# 26250       1
# 24540       1
# Name: AC Output Total Power (Active)(W), Length: 2617, dtype: int64
# 49.99    3466
# 50.00    2040
# 50.03    1991
# 50.01    1752
# 50.06    1570
#          ...
# 49.53       1
# 49.50       1
# 51.42       1
# 51.51       1
# 51.22       1
# Name: AC Output Frequency R(Hz), Length: 113, dtype: int64
# 2544    4672
# 3164    4532
# 3833    4528
# 3225    4294
# 3374    4268
# 2835     983
# Name: Generation of Last Month (Active)(kWh), dtype: int64
# 0.0      849
# 0.1      376
# 0.2      206
# 0.3      165
# 0.4      146
#         ...
# 153.3      1
# 153.4      1
# 149.4      1
# 153.6      1
# 142.2      1
# Name: Daily Generation (Active)(kWh), Length: 1535, dtype: int64
# 126395.0    54
# 133206.0    54
# 127161.0    43
# 124934.0    42
# 126091.0    42
#             ..
# 119746.0     1
# 119748.0     1
# 119750.0     1
# 119752.0     1
# 127416.0     1
# Name: Total Generation (Active)(kWh), Length: 12584, dtype: int64
# 0        507
# 50       232
# 100      204
# 80       151
# 40       148
#         ...
# 21810      1
# 27490      1
# 25750      1
# 28000      1
# 24860      1
# Name: Power Grid Total Apparent Power(VA), Length: 2607, dtype: int64
# 1.0    23277
# Name: Grid Power Factor, dtype: int64
# 41.0    135
# 35.3    116
# 42.0    109
# 40.0    105
# 44.0    100
#        ...
# 72.6      1
# 72.5      1
# 72.7      1
# 72.1      1
# 25.1      1
# Name: Inverter Temperature(℃), Length: 489, dtype: int64
# 1022       22835
# 1025         415
# Standby       27
# Name: Inverter Status, dtype: int64
# 118.1    311
# 118.9    309
# 29.8     292
# 119.9    291
# 79.3     287
#         ...
# 124.7    108
# 111.9    105
# 93.3      82
# 78.1      19
# 0.0        5
# Name: Generation Yesterday(kWh), Length: 153, dtype: int64

# %% [markdown]
# Conclusion:Alert details, Alert code, Grid power factor, Inverter status attributes doesnt have much unique values

# %%
d=d[['Time', 'DC Voltage PV1(V)', 'DC Voltage PV2(V)', 'DC Voltage PV3(V)',
       'DC Voltage PV4(V)', 'DC Current1(A)', 'DC Current2(A)',
       'DC Current3(A)', 'DC Current4(A)', 'Total DC Input Power(W)',
       'AC Voltage R/U/A(V)', 'AC Voltage S/V/B(V)', 'AC Voltage T/W/C(V)',
       'AC Current R/U/A(A)', 'AC Current S/V/B(A)', 'AC Current T/W/C(A)',
       'AC Output Total Power (Active)(W)', 'AC Output Frequency R(Hz)',
       'Generation of Last Month (Active)(kWh)',
       'Daily Generation (Active)(kWh)', 'Total Generation (Active)(kWh)',
       'Power Grid Total Apparent Power(VA)',
       'Inverter Temperature(℃)',
       'Generation Yesterday(kWh)']]

# %%
d.head(10)
# Out:
#                Time  DC Voltage PV1(V)  DC Voltage PV2(V)  DC Voltage PV3(V)  \
# 0  2022/05/02 05:55               92.2              165.4               94.8
# 1  2022/05/02 06:00              200.1              236.2              200.1
# 2  2022/05/02 06:05              207.8              344.2              216.1
# 3  2022/05/02 06:12              228.1              596.1              228.0
# 4  2022/05/02 06:17              240.1              608.1              240.1
# 5  2022/05/02 06:22              268.1              603.6              267.8
# 6  2022/05/02 06:27              548.0              611.8              523.9
# 7  2022/05/02 06:33              616.0              624.0              632.1
# 8  2022/05/02 06:38              628.1              628.0              628.3
# 9  2022/05/02 06:43              627.8              635.3              628.1
#
#    DC Voltage PV4(V)  DC Current1(A)  DC Current2(A)  DC Current3(A)  \
# 0               86.5             0.1             0.1             0.1
# 1              536.4             0.1             0.2             0.1
# 2              536.4             0.1             0.2             0.1
# 3              536.3             0.2             0.3             0.2
# 4              536.6             0.2             0.3             0.2
# 5              252.1             0.2             0.4             0.2
# 6              452.3             0.3             0.5             0.3
# 7              664.1             0.3             0.6             0.3
# 8              660.0             0.4             0.8             0.4
# 9              667.7             0.6             1.0             0.6
#
#    DC Current4(A)  Total DC Input Power(W)  ...  AC Current S/V/B(A)  \
# 0             0.1                       43  ...                  0.0
# 1             0.1                      140  ...                  0.1
# 2             0.1                      164  ...                  0.2
# 3             0.2                      377  ...                  0.4
# 4             0.2                      385  ...                  0.5
# 5             0.2                      399  ...                  0.5
# 6             0.3                      763  ...                  0.9
# 7             0.3                      948  ...                  1.4
# 8             0.4                     1268  ...                  1.7
# 9             0.5                     1722  ...                  2.4
#
#    AC Current T/W/C(A)  AC Output Total Power (Active)(W)  \
# 0                  0.0                                 20
# 1                  0.1                                 30
# 2                  0.2                                 40
# 3                  0.4                                200
# 4                  0.5                                160
# 5                  0.5                                220
# 6                  0.9                                500
# 7                  1.3                                740
# 8                  1.7                               1080
# 9                  2.3                               1540
#
#    AC Output Frequency R(Hz)  Generation of Last Month (Active)(kWh)  \
# 0                      50.00                                    3164
# 1                      50.10                                    3164
# 2                      50.11                                    3164
# 3                      50.01                                    3164
# 4                      50.06                                    3164
# 5                      50.05                                    3164
# 6                      50.03                                    3164
# 7                      49.99                                    3164
# 8                      50.06                                    3164
# 9                      50.01                                    3164
#
#    Daily Generation (Active)(kWh)  Total Generation (Active)(kWh)  \
# 0                             0.0                        117029.0
# 1                             0.0                        117029.0
# 2                             0.0                        117029.0
# 3                             0.0                        117029.0
# 4                             0.0                        117029.0
# 5                             0.1                        117029.0
# 6                             0.1                        117029.0
# 7                             0.1                        117029.0
# 8                             0.2                        117029.0
# 9                             0.3                        117029.0
#
#    Power Grid Total Apparent Power(VA)  Inverter Temperature(℃)  \
# 0                                   80                     32.9
# 1                                   20                     34.1
# 2                                   30                     34.4
# 3                                  190                     34.9
# 4                                  160                     35.3
# 5                                  240                     35.4
# 6                                  480                     35.7
# 7                                  710                     36.1
# 8                                 1080                     36.5
# 9                                 1530                     36.8
#
#    Generation Yesterday(kWh)
# 0                      126.9
# 1                      126.9
# 2                      126.9
# 3                      126.9
# 4                      126.9
# 5                      126.9
# 6                      126.9
# 7                      126.9
# 8                      126.9
# 9                      126.9
#
# [10 rows x 24 columns]

# %%
d.isna().sum()
# Out:
# Time                                      0
# DC Voltage PV1(V)                         0
# DC Voltage PV2(V)                         0
# DC Voltage PV3(V)                         0
# DC Voltage PV4(V)                         0
# DC Current1(A)                            0
# DC Current2(A)                            0
# DC Current3(A)                            0
# DC Current4(A)                            0
# Total DC Input Power(W)                   0
# AC Voltage R/U/A(V)                       0
# AC Voltage S/V/B(V)                       0
# AC Voltage T/W/C(V)                       0
# AC Current R/U/A(A)                       0
# AC Current S/V/B(A)                       0
# AC Current T/W/C(A)                       0
# AC Output Total Power (Active)(W)         0
# AC Output Frequency R(Hz)                 0
# Generation of Last Month (Active)(kWh)    0
# Daily Generation (Active)(kWh)            0
# Total Generation (Active)(kWh)            0
# Power Grid Total Apparent Power(VA)       0
# Inverter Temperature(℃)                   0
# Generation Yesterday(kWh)                 0
# dtype: int64

# %% [markdown]
# # Converting to datetime

# %%
d.dtypes
# Out:
# Time                                       object
# DC Voltage PV1(V)                         float64
# DC Voltage PV2(V)                         float64
# DC Voltage PV3(V)                         float64
# DC Voltage PV4(V)                         float64
# DC Current1(A)                            float64
# DC Current2(A)                            float64
# DC Current3(A)                            float64
# DC Current4(A)                            float64
# Total DC Input Power(W)                     int64
# AC Voltage R/U/A(V)                       float64
# AC Voltage S/V/B(V)                       float64
# AC Voltage T/W/C(V)                       float64
# AC Current R/U/A(A)                       float64
# AC Current S/V/B(A)                       float64
# AC Current T/W/C(A)                       float64
# AC Output Total Power (Active)(W)           int64
# AC Output Frequency R(Hz)                 float64
# Generation of Last Month (Active)(kWh)      int64
# Daily Generation (Active)(kWh)            float64
# Total Generation (Active)(kWh)            float64
# Power Grid Total Apparent Power(VA)         int64
# Inverter Temperature(℃)                   float64
# Generation Yesterday(kWh)                 float64
# dtype: object

# %%
d.loc[:,'Time'] = d['Time'].astype('string')#converted time to string
d.dtypes
# Out:
# c:\Users\aksha\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# Time                                       string
# DC Voltage PV1(V)                         float64
# DC Voltage PV2(V)                         float64
# DC Voltage PV3(V)                         float64
# DC Voltage PV4(V)                         float64
# DC Current1(A)                            float64
# DC Current2(A)                            float64
# DC Current3(A)                            float64
# DC Current4(A)                            float64
# Total DC Input Power(W)                     int64
# AC Voltage R/U/A(V)                       float64
# AC Voltage S/V/B(V)                       float64
# AC Voltage T/W/C(V)                       float64
# AC Current R/U/A(A)                       float64
# AC Current S/V/B(A)                       float64
# AC Current T/W/C(A)                       float64
# AC Output Total Power (Active)(W)           int64
# AC Output Frequency R(Hz)                 float64
# Generation of Last Month (Active)(kWh)      int64
# Daily Generation (Active)(kWh)            float64
# Total Generation (Active)(kWh)            float64
# Power Grid Total Apparent Power(VA)         int64
# Inverter Temperature(℃)                   float64
# Generation Yesterday(kWh)                 float64
# dtype: object

# %%
d['Time']= pd.to_datetime(d['Time'])
d.dtypes
# Out:
# c:\Users\aksha\Anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# Time                                      datetime64[ns]
# DC Voltage PV1(V)                                float64
# DC Voltage PV2(V)                                float64
# DC Voltage PV3(V)                                float64
# DC Voltage PV4(V)                                float64
# DC Current1(A)                                   float64
# DC Current2(A)                                   float64
# DC Current3(A)                                   float64
# DC Current4(A)                                   float64
# Total DC Input Power(W)                            int64
# AC Voltage R/U/A(V)                              float64
# AC Voltage S/V/B(V)                              float64
# AC Voltage T/W/C(V)                              float64
# AC Current R/U/A(A)                              float64
# AC Current S/V/B(A)                              float64
# AC Current T/W/C(A)                              float64
# AC Output Total Power (Active)(W)                  int64
# AC Output Frequency R(Hz)                        float64
# Generation of Last Month (Active)(kWh)             int64
# Daily Generation (Active)(kWh)                   float64
# Total Generation (Active)(kWh)                   float64
# Power Grid Total Apparent Power(VA)                int64
# Inverter Temperature(℃)                          float64
# Generation Yesterday(kWh)                        float64
# dtype: object

# %%
d.head()
# Out:
#                  Time  DC Voltage PV1(V)  DC Voltage PV2(V)  \
# 0 2022-05-02 05:55:00               92.2              165.4
# 1 2022-05-02 06:00:00              200.1              236.2
# 2 2022-05-02 06:05:00              207.8              344.2
# 3 2022-05-02 06:12:00              228.1              596.1
# 4 2022-05-02 06:17:00              240.1              608.1
#
#    DC Voltage PV3(V)  DC Voltage PV4(V)  DC Current1(A)  DC Current2(A)  \
# 0               94.8               86.5             0.1             0.1
# 1              200.1              536.4             0.1             0.2
# 2              216.1              536.4             0.1             0.2
# 3              228.0              536.3             0.2             0.3
# 4              240.1              536.6             0.2             0.3
#
#    DC Current3(A)  DC Current4(A)  Total DC Input Power(W)  ...  \
# 0             0.1             0.1                       43  ...
# 1             0.1             0.1                      140  ...
# 2             0.1             0.1                      164  ...
# 3             0.2             0.2                      377  ...
# 4             0.2             0.2                      385  ...
#
#    AC Current S/V/B(A)  AC Current T/W/C(A)  \
# 0                  0.0                  0.0
# 1                  0.1                  0.1
# 2                  0.2                  0.2
# 3                  0.4                  0.4
# 4                  0.5                  0.5
#
#    AC Output Total Power (Active)(W)  AC Output Frequency R(Hz)  \
# 0                                 20                      50.00
# 1                                 30                      50.10
# 2                                 40                      50.11
# 3                                200                      50.01
# 4                                160                      50.06
#
#    Generation of Last Month (Active)(kWh)  Daily Generation (Active)(kWh)  \
# 0                                    3164                             0.0
# 1                                    3164                             0.0
# 2                                    3164                             0.0
# 3                                    3164                             0.0
# 4                                    3164                             0.0
#
#    Total Generation (Active)(kWh)  Power Grid Total Apparent Power(VA)  \
# 0                        117029.0                                   80
# 1                        117029.0                                   20
# 2                        117029.0                                   30
# 3                        117029.0                                  190
# 4                        117029.0                                  160
#
#    Inverter Temperature(℃)  Generation Yesterday(kWh)
# 0                     32.9                      126.9
# 1                     34.1                      126.9
# 2                     34.4                      126.9
# 3                     34.9                      126.9
# 4                     35.3                      126.9
#
# [5 rows x 24 columns]

# %% [markdown]
# # Outlier analysis and removal

# %%
from datetime import date

# %%
dates=d
s=dates['Time'].apply(lambda x: x.date()).value_counts()# checking outliers
s
# Out:
# 2022-06-07    174
# 2022-06-14    169
# 2022-06-08    168
# 2022-08-03    165
# 2022-06-05    163
#              ...
# 2022-05-27    108
# 2022-09-29    105
# 2022-06-29     82
# 2022-10-05     19
# 2022-10-06      5
# Name: Time, Length: 159, dtype: int64

# %%
import matplotlib.pyplot as plt
s.plot()
plt.show()

# %%
outliersN=pd.read_csv("no_outliers.csv")# outliers removed using excel
outliersN
# Out:
#                    Time  DC Voltage PV1(V)  DC Voltage PV2(V)  \
# 0      02-05-2022 05:55               92.2              165.4
# 1      02-05-2022 06:00              200.1              236.2
# 2      02-05-2022 06:05              207.8              344.2
# 3      02-05-2022 06:12              228.1              596.1
# 4      02-05-2022 06:17              240.1              608.1
# ...                 ...                ...                ...
# 23248  09-10-2022 17:53              200.0              546.6
# 23249  09-10-2022 17:58              199.9              200.1
# 23250  09-10-2022 18:03              457.3              200.0
# 23251  09-10-2022 18:09              437.6              420.4
# 23252  09-10-2022 18:14              193.3              258.8
#
#        DC Voltage PV3(V)  DC Voltage PV4(V)  DC Current1(A)  DC Current2(A)  \
# 0                   94.8               86.5             0.1             0.1
# 1                  200.1              536.4             0.1             0.2
# 2                  216.1              536.4             0.1             0.2
# 3                  228.0              536.3             0.2             0.3
# 4                  240.1              536.6             0.2             0.3
# ...                  ...                ...             ...             ...
# 23248              200.0              200.0             0.1             0.1
# 23249              476.1              509.6             0.1             0.1
# 23250              476.3              509.6             0.1             0.1
# 23251              382.1              389.7             0.1             0.1
# 23252              184.9              188.8             0.1             0.1
#
#        DC Current3(A)  DC Current4(A)  Total DC Input Power(W)  ...  \
# 0                 0.1             0.1                       43  ...
# 1                 0.1             0.1                      140  ...
# 2                 0.1             0.1                      164  ...
# 3                 0.2             0.2                      377  ...
# 4                 0.2             0.2                      385  ...
# ...               ...             ...                      ...  ...
# 23248             0.1             0.1                      114  ...
# 23249             0.1             0.1                      138  ...
# 23250             0.1             0.1                      164  ...
# 23251             0.1             0.1                      162  ...
# 23252             0.1             0.1                       82  ...
#
#        AC Current S/V/B(A)  AC Current T/W/C(A)  \
# 0                      0.0                  0.0
# 1                      0.1                  0.1
# 2                      0.2                  0.2
# 3                      0.4                  0.4
# 4                      0.5                  0.5
# ...                    ...                  ...
# 23248                  0.1                  0.1
# 23249                  0.0                  0.0
# 23250                  0.0                  0.0
# 23251                  0.0                  0.0
# 23252                  0.0                  0.0
#
#        AC Output Total Power (Active)(W)  AC Output Frequency R(Hz)  \
# 0                                     20                      50.00
# 1                                     30                      50.10
# 2                                     40                      50.11
# 3                                    200                      50.01
# 4                                    160                      50.06
# ...                                  ...                        ...
# 23248                                 20                      49.99
# 23249                                 20                      50.03
# 23250                                 20                      50.06
# 23251                                 20                      49.96
# 23252                                 20                      50.03
#
#        Generation of Last Month (Active)(kWh)  Daily Generation (Active)(kWh)  \
# 0                                        3164                             0.0
# 1                                        3164                             0.0
# 2                                        3164                             0.0
# 3                                        3164                             0.0
# 4                                        3164                             0.0
# ...                                       ...                             ...
# 23248                                    2835                            82.4
# 23249                                    2835                            82.4
# 23250                                    2835                            82.4
# 23251                                    2835                            82.4
# 23252                                    2835                            82.4
#
#        Total Generation (Active)(kWh)  Power Grid Total Apparent Power(VA)  \
# 0                              117029                                   80
# 1                              117029                                   20
# 2                              117029                                   30
# 3                              117029                                  190
# 4                              117029                                  160
# ...                               ...                                  ...
# 23248                          133462                                   80
# 23249                          133462                                   70
# 23250                          133462                                  140
# 23251                          133462                                  140
# 23252                          133462                                  130
#
#        Inverter Temperature(℃)  Generation Yesterday(kWh)
# 0                         32.9                      126.9
# 1                         34.1                      126.9
# 2                         34.4                      126.9
# 3                         34.9                      126.9
# 4                         35.3                      126.9
# ...                        ...                        ...
# 23248                     37.8                      131.9
# 23249                     37.6                      131.9
# 23250                     37.4                      131.9
# 23251                     37.1                      131.9
# 23252                     36.8                      131.9
#
# [23253 rows x 24 columns]

# %%
outliersN.loc[:,'Time'] = outliersN['Time'].astype('string')#converted time to string
outliersN.dtypes
# Out:
# Time                                       string
# DC Voltage PV1(V)                         float64
# DC Voltage PV2(V)                         float64
# DC Voltage PV3(V)                         float64
# DC Voltage PV4(V)                         float64
# DC Current1(A)                            float64
# DC Current2(A)                            float64
# DC Current3(A)                            float64
# DC Current4(A)                            float64
# Total DC Input Power(W)                     int64
# AC Voltage R/U/A(V)                       float64
# AC Voltage S/V/B(V)                       float64
# AC Voltage T/W/C(V)                       float64
# AC Current R/U/A(A)                       float64
# AC Current S/V/B(A)                       float64
# AC Current T/W/C(A)                       float64
# AC Output Total Power (Active)(W)           int64
# AC Output Frequency R(Hz)                 float64
# Generation of Last Month (Active)(kWh)      int64
# Daily Generation (Active)(kWh)            float64
# Total Generation (Active)(kWh)              int64
# Power Grid Total Apparent Power(VA)         int64
# Inverter Temperature(℃)                   float64
# Generation Yesterday(kWh)                 float64
# dtype: object

# %%
outliersN['Time']= pd.to_datetime(outliersN['Time'])
outliersN.dtypes
# Out:
# Time                                      datetime64[ns]
# DC Voltage PV1(V)                                float64
# DC Voltage PV2(V)                                float64
# DC Voltage PV3(V)                                float64
# DC Voltage PV4(V)                                float64
# DC Current1(A)                                   float64
# DC Current2(A)                                   float64
# DC Current3(A)                                   float64
# DC Current4(A)                                   float64
# Total DC Input Power(W)                            int64
# AC Voltage R/U/A(V)                              float64
# AC Voltage S/V/B(V)                              float64
# AC Voltage T/W/C(V)                              float64
# AC Current R/U/A(A)                              float64
# AC Current S/V/B(A)                              float64
# AC Current T/W/C(A)                              float64
# AC Output Total Power (Active)(W)                  int64
# AC Output Frequency R(Hz)                        float64
# Generation of Last Month (Active)(kWh)             int64
# Daily Generation (Active)(kWh)                   float64
# Total Generation (Active)(kWh)                     int64
# Power Grid Total Apparent Power(VA)                int64
# Inverter Temperature(℃)                          float64
# Generation Yesterday(kWh)                        float64
# dtype: object

# %% [markdown]
# # Common time interval(6-7)

# %%
from datetime import time
d1=outliersN[outliersN['Time'].apply(lambda x: x.time()) < time(19,00,00)]
d1
# Out:
#                      Time  DC Voltage PV1(V)  DC Voltage PV2(V)  \
# 0     2022-02-05 05:55:00               92.2              165.4
# 1     2022-02-05 06:00:00              200.1              236.2
# 2     2022-02-05 06:05:00              207.8              344.2
# 3     2022-02-05 06:12:00              228.1              596.1
# 4     2022-02-05 06:17:00              240.1              608.1
# ...                   ...                ...                ...
# 23248 2022-09-10 17:53:00              200.0              546.6
# 23249 2022-09-10 17:58:00              199.9              200.1
# 23250 2022-09-10 18:03:00              457.3              200.0
# 23251 2022-09-10 18:09:00              437.6              420.4
# 23252 2022-09-10 18:14:00              193.3              258.8
#
#        DC Voltage PV3(V)  DC Voltage PV4(V)  DC Current1(A)  DC Current2(A)  \
# 0                   94.8               86.5             0.1             0.1
# 1                  200.1              536.4             0.1             0.2
# 2                  216.1              536.4             0.1             0.2
# 3                  228.0              536.3             0.2             0.3
# 4                  240.1              536.6             0.2             0.3
# ...                  ...                ...             ...             ...
# 23248              200.0              200.0             0.1             0.1
# 23249              476.1              509.6             0.1             0.1
# 23250              476.3              509.6             0.1             0.1
# 23251              382.1              389.7             0.1             0.1
# 23252              184.9              188.8             0.1             0.1
#
#        DC Current3(A)  DC Current4(A)  Total DC Input Power(W)  ...  \
# 0                 0.1             0.1                       43  ...
# 1                 0.1             0.1                      140  ...
# 2                 0.1             0.1                      164  ...
# 3                 0.2             0.2                      377  ...
# 4                 0.2             0.2                      385  ...
# ...               ...             ...                      ...  ...
# 23248             0.1             0.1                      114  ...
# 23249             0.1             0.1                      138  ...
# 23250             0.1             0.1                      164  ...
# 23251             0.1             0.1                      162  ...
# 23252             0.1             0.1                       82  ...
#
#        AC Current S/V/B(A)  AC Current T/W/C(A)  \
# 0                      0.0                  0.0
# 1                      0.1                  0.1
# 2                      0.2                  0.2
# 3                      0.4                  0.4
# 4                      0.5                  0.5
# ...                    ...                  ...
# 23248                  0.1                  0.1
# 23249                  0.0                  0.0
# 23250                  0.0                  0.0
# 23251                  0.0                  0.0
# 23252                  0.0                  0.0
#
#        AC Output Total Power (Active)(W)  AC Output Frequency R(Hz)  \
# 0                                     20                      50.00
# 1                                     30                      50.10
# 2                                     40                      50.11
# 3                                    200                      50.01
# 4                                    160                      50.06
# ...                                  ...                        ...
# 23248                                 20                      49.99
# 23249                                 20                      50.03
# 23250                                 20                      50.06
# 23251                                 20                      49.96
# 23252                                 20                      50.03
#
#        Generation of Last Month (Active)(kWh)  Daily Generation (Active)(kWh)  \
# 0                                        3164                             0.0
# 1                                        3164                             0.0
# 2                                        3164                             0.0
# 3                                        3164                             0.0
# 4                                        3164                             0.0
# ...                                       ...                             ...
# 23248                                    2835                            82.4
# 23249                                    2835                            82.4
# 23250                                    2835                            82.4
# 23251                                    2835                            82.4
# 23252                                    2835                            82.4
#
#        Total Generation (Active)(kWh)  Power Grid Total Apparent Power(VA)  \
# 0                              117029                                   80
# 1                              117029                                   20
# 2                              117029                                   30
# 3                              117029                                  190
# 4                              117029                                  160
# ...                               ...                                  ...
# 23248                          133462                                   80
# 23249                          133462                                   70
# 23250                          133462                                  140
# 23251                          133462                                  140
# 23252                          133462                                  130
#
#        Inverter Temperature(℃)  Generation Yesterday(kWh)
# 0                         32.9                      126.9
# 1                         34.1                      126.9
# 2                         34.4                      126.9
# 3                         34.9                      126.9
# 4                         35.3                      126.9
# ...                        ...                        ...
# 23248                     37.8                      131.9
# 23249                     37.6                      131.9
# 23250                     37.4                      131.9
# 23251                     37.1                      131.9
# 23252                     36.8                      131.9
#
# [23126 rows x 24 columns]

# %%
d1=d1[d1['Time'].apply(lambda x: x.time()) >= time(6,00,00)]
d1
# Out:
#                      Time  DC Voltage PV1(V)  DC Voltage PV2(V)  \
# 1     2022-02-05 06:00:00              200.1              236.2
# 2     2022-02-05 06:05:00              207.8              344.2
# 3     2022-02-05 06:12:00              228.1              596.1
# 4     2022-02-05 06:17:00              240.1              608.1
# 5     2022-02-05 06:22:00              268.1              603.6
# ...                   ...                ...                ...
# 23248 2022-09-10 17:53:00              200.0              546.6
# 23249 2022-09-10 17:58:00              199.9              200.1
# 23250 2022-09-10 18:03:00              457.3              200.0
# 23251 2022-09-10 18:09:00              437.6              420.4
# 23252 2022-09-10 18:14:00              193.3              258.8
#
#        DC Voltage PV3(V)  DC Voltage PV4(V)  DC Current1(A)  DC Current2(A)  \
# 1                  200.1              536.4             0.1             0.2
# 2                  216.1              536.4             0.1             0.2
# 3                  228.0              536.3             0.2             0.3
# 4                  240.1              536.6             0.2             0.3
# 5                  267.8              252.1             0.2             0.4
# ...                  ...                ...             ...             ...
# 23248              200.0              200.0             0.1             0.1
# 23249              476.1              509.6             0.1             0.1
# 23250              476.3              509.6             0.1             0.1
# 23251              382.1              389.7             0.1             0.1
# 23252              184.9              188.8             0.1             0.1
#
#        DC Current3(A)  DC Current4(A)  Total DC Input Power(W)  ...  \
# 1                 0.1             0.1                      140  ...
# 2                 0.1             0.1                      164  ...
# 3                 0.2             0.2                      377  ...
# 4                 0.2             0.2                      385  ...
# 5                 0.2             0.2                      399  ...
# ...               ...             ...                      ...  ...
# 23248             0.1             0.1                      114  ...
# 23249             0.1             0.1                      138  ...
# 23250             0.1             0.1                      164  ...
# 23251             0.1             0.1                      162  ...
# 23252             0.1             0.1                       82  ...
#
#        AC Current S/V/B(A)  AC Current T/W/C(A)  \
# 1                      0.1                  0.1
# 2                      0.2                  0.2
# 3                      0.4                  0.4
# 4                      0.5                  0.5
# 5                      0.5                  0.5
# ...                    ...                  ...
# 23248                  0.1                  0.1
# 23249                  0.0                  0.0
# 23250                  0.0                  0.0
# 23251                  0.0                  0.0
# 23252                  0.0                  0.0
#
#        AC Output Total Power (Active)(W)  AC Output Frequency R(Hz)  \
# 1                                     30                      50.10
# 2                                     40                      50.11
# 3                                    200                      50.01
# 4                                    160                      50.06
# 5                                    220                      50.05
# ...                                  ...                        ...
# 23248                                 20                      49.99
# 23249                                 20                      50.03
# 23250                                 20                      50.06
# 23251                                 20                      49.96
# 23252                                 20                      50.03
#
#        Generation of Last Month (Active)(kWh)  Daily Generation (Active)(kWh)  \
# 1                                        3164                             0.0
# 2                                        3164                             0.0
# 3                                        3164                             0.0
# 4                                        3164                             0.0
# 5                                        3164                             0.1
# ...                                       ...                             ...
# 23248                                    2835                            82.4
# 23249                                    2835                            82.4
# 23250                                    2835                            82.4
# 23251                                    2835                            82.4
# 23252                                    2835                            82.4
#
#        Total Generation (Active)(kWh)  Power Grid Total Apparent Power(VA)  \
# 1                              117029                                   20
# 2                              117029                                   30
# 3                              117029                                  190
# 4                              117029                                  160
# 5                              117029                                  240
# ...                               ...                                  ...
# 23248                          133462                                   80
# 23249                          133462                                   70
# 23250                          133462                                  140
# 23251                          133462                                  140
# 23252                          133462                                  130
#
#        Inverter Temperature(℃)  Generation Yesterday(kWh)
# 1                         34.1                      126.9
# 2                         34.4                      126.9
# 3                         34.9                      126.9
# 4                         35.3                      126.9
# 5                         35.4                      126.9
# ...                        ...                        ...
# 23248                     37.8                      131.9
# 23249                     37.6                      131.9
# 23250                     37.4                      131.9
# 23251                     37.1                      131.9
# 23252                     36.8                      131.9
#
# [22952 rows x 24 columns]

# %% [markdown]
# # Converting to 1 HR intervals

# %%
#d1.set_index('Time',inplace= True)

# %%
#df=d1
#df=df.resample("1H").mean()
#df

# %%
#times=df.reset_index()
#times

# %%
#times['actual time']=times['Time'].apply(lambda x: x.time())
#times[times['actual time']==time(6,00,00)]
